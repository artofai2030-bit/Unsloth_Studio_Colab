# %% [markdown]
# <a href="https://colab.research.google.com/github/artofai2030-bit/Unsloth_Studio_Colab/blob/main/studio/Unsloth_Studio_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth Studio on your local device, follow [our guide](https://unsloth.ai/docs/new/unsloth-studio/install). Unsloth Studio is licensed [AGPL-3.0](https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0).
#
# ### Unsloth Studio
#
# Train and run open models with [**Unsloth Studio**](https://unsloth.ai/docs/new/unsloth-studio/start). Currently, installation may take 30+ mins so use a newer GPU.
#
#
# We are actively working on making Unsloth Studio install on Colab T4 GPUs faster.
#
# [Features](https://unsloth.ai/docs/new/unsloth-studio#features) • [Quickstart](https://unsloth.ai/docs/new/unsloth-studio/start) • [Data Recipes](https://unsloth.ai/docs/new/unsloth-studio/data-recipe) • [Studio Chat](https://unsloth.ai/docs/new/unsloth-studio/chat) • [Export](https://unsloth.ai/docs/new/unsloth-studio/export)

# %% [markdown]
# <p align="left"><img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/studio%20github%20landscape%20colab%20display.png" width="600"></p>

# %% [markdown]
# ### Setup: Clone repo and run setup

# %%
# !git clone --depth 1 --branch main https://github.com/unslothai/unsloth.git
# %cd /content/unsloth

# Run setup script
# !chmod +x studio/setup.sh
# !./studio/setup.sh
# Out:
# Cloning into 'unsloth'...
# remote: Enumerating objects: 1004, done.
# remote: Counting objects: 100% (1004/1004), done.
# remote: Compressing objects: 100% (831/831), done.
# remote: Total 1004 (delta 179), reused 705 (delta 154), pack-reused 0 (from 0)
# Receiving objects: 100% (1004/1004), 30.96 MiB | 27.24 MiB/s, done.
# Resolving deltas: 100% (179/179), done.
# /content/unsloth
# ╔══════════════════════════════════════╗
# ║     Unsloth Studio Setup Script      ║
# ╚══════════════════════════════════════╝
# ✅ Node v20.19.0 and npm 10.8.2 detected in Colab.
#    Upgrading npm to latest...
# ✅ Node v20.19.0 | npm 11.12.0
# ✅ Frontend built to frontend/dist
# finished finding best python
# ✅ Using python3 (3.12.12) — compatible (3.11.x – 3.13.x)
# [====================] 11/11  finalizing
# ✅ Python dependencies installed
#
#    Pre-installing transformers 5.x for newer model support...
# ✅ Transformers 5.x pre-installed to /root/.unsloth/studio/.venv_t5/
#
# Building llama-server for GGUF inference...
#    Building with CUDA support (nvcc: /usr/local/cuda/bin/nvcc)...
#    GPU compute capabilities: 75 -- limiting build to detected archs
# ✅ llama-server built at /root/.unsloth/llama.cpp/build/bin/llama-server
# ✅ llama-quantize available for GGUF export
#
# ╔══════════════════════════════════════╗
# ║           Setup Complete!            ║
# ╠══════════════════════════════════════╣
# ║ Unsloth Studio is ready to start     ║
# ║ in your Colab notebook!              ║
# ║                                      ║
# ║ from colab import start              ║
# ║ start()                              ║
# ╚══════════════════════════════════════╝

# %% [markdown]
# ### Start Unsloth Studio

# %%
import sys
sys.path.insert(0, '/content/unsloth/studio/backend')

from colab import start
start()
# Out:
# {"timestamp": "2026-03-21T09:49:46.311355Z", "level": "info", "event": "\ud83e\udda5 Starting Unsloth Studio..."}
# {"timestamp": "2026-03-21T09:49:46.312736Z", "level": "info", "event": "   Loading backend..."}
# {"timestamp": "2026-03-21T09:49:46.313690Z", "level": "info", "event": "   Starting server..."}
# INFO:     Started server process [2080]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8889 (Press CTRL+C to quit)
# Hardware detected: CUDA — Tesla T4
# {"timestamp": "2026-03-21T09:49:46.507620Z", "level": "info", "event": "Pre-caching helper GGUF: unsloth/Qwen3.5-4B-GGUF/Qwen3.5-4B-UD-Q4_K_XL.gguf"}
# {"timestamp": "2026-03-21T09:49:49.320634Z", "level": "info", "event": "   Server started!"}
#     <div style="display: inline-block; padding: 20px; background: #ffffff; border: 2px solid #000000;
#                 border-radius: 12px; margin: 10px 0; font-family: system-ui, -apple-system, sans-serif;">
#         <h2 style="color: #000000; margin: 0 0 12px 0; font-size: 26px; font-weight: 800;
#                    display: flex; align-items: center; gap: 12px;">
#             <img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/unsloth-gem.png"
#                  height="48" style="display:block;">
#             Unsloth Studio is Ready!
#         </h2>
#         <a href="https://8888-gpu-t4-s-kkb-usw4a2-1gzye2nf8ldt3-a.us-west4-2.prod.colab.dev" target="_blank"
#            style="display: inline-flex; align-items: center; gap: 10px; padding: 14px 28px;
#                   background: #000000; color: white; text-decoration: none; border-radius: 8px;
#                   font-weight: 800; font-size: 16px;">
#             <svg xmlns="http://www.w3.org/2000/svg" width="18" height="18" viewBox="0 0 24 24" fill="white"><polygon points="5,3 19,12 5,21"/></svg>
#             Open Unsloth Studio
#         </a>
#         <p style="color: #333333; margin: 16px 0 0 0; font-size: 13px; font-family: monospace;">
#             https://8888-gpu-...
#         </p>
#     </div>

# %%
import time
while True:
    time.sleep(60)
# Out:
# {"timestamp": "2026-03-21T09:53:17.930959Z", "level": "info", "event": "Getting model config for: unsloth/qwen3.5-2b"}
# {"timestamp": "2026-03-21T09:53:17.938883Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-03-21T09:53:17.943400Z", "level": "info", "event": "Model 'unsloth/qwen3.5-2b' needs transformers 5.x \u2014 checking vision via subprocess"}
# {"timestamp": "2026-03-21T09:53:33.004801Z", "level": "info", "event": "Vision check (subprocess, transformers 5.x) for 'unsloth/qwen3.5-2b': model_type=qwen3_5, architectures=['Qwen3_5ForConditionalGeneration'], is_vision=True"}
# {"timestamp": "2026-03-21T09:53:34.035002Z", "level": "info", "event": "Model 'unsloth/qwen3.5-2b' needs transformers 5.x \u2014 checking vision via subprocess"}
# {"timestamp": "2026-03-21T09:53:39.600342Z", "level": "info", "event": "Vision check (subprocess, transformers 5.x) for 'unsloth/qwen3.5-2b': model_type=qwen3_5, architectures=['Qwen3_5ForConditionalGeneration'], is_vision=True"}
# config.json: 0.00B [00:00, ?B/s]
# {"timestamp": "2026-03-21T09:53:39.802305Z", "level": "info", "event": "Model config result for unsloth/qwen3.5-2b: is_vision=True, is_embedding=False, audio_type=None, is_lora=False, max_position_embeddings=None"}
# {"timestamp": "2026-03-21T09:53:39.956131Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/config/unsloth/Qwen3.5-2B", "status_code": 200, "process_time_ms": 22027.74}
# {"timestamp": "2026-03-21T09:53:46.666924Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.79}
# {"timestamp": "2026-03-21T09:53:48.107984Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/data-recipes", "status_code": 200, "process_time_ms": 1.8}
# {"timestamp": "2026-03-21T09:54:19.448369Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 1.05}
# {"timestamp": "2026-03-21T09:55:26.669231Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 0.56}
# {"timestamp": "2026-03-21T09:55:27.140240Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.43}
# {"timestamp": "2026-03-21T09:55:27.685536Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.44}
# {"timestamp": "2026-03-21T09:57:00.742758Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/studio", "status_code": 200, "process_time_ms": 1.39}
# {"timestamp": "2026-03-21T09:57:57.815931Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 0.5}
# {"timestamp": "2026-03-21T09:57:58.339951Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.41}
# {"timestamp": "2026-03-21T10:00:08.040145Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 2.1}
# {"timestamp": "2026-03-21T10:00:08.533208Z", "level": "info", "event": "Getting model config for: unsloth/qwen3.5-2b"}
# {"timestamp": "2026-03-21T10:00:08.540863Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-03-21T10:00:08.542460Z", "level": "info", "event": "Model 'unsloth/qwen3.5-2b' needs transformers 5.x \u2014 checking vision via subprocess"}
# {"timestamp": "2026-03-21T10:00:13.987555Z", "level": "info", "event": "Vision check (subprocess, transformers 5.x) for 'unsloth/qwen3.5-2b': model_type=qwen3_5, architectures=['Qwen3_5ForConditionalGeneration'], is_vision=True"}
# {"timestamp": "2026-03-21T10:00:14.376718Z", "level": "info", "event": "Model 'unsloth/qwen3.5-2b' needs transformers 5.x \u2014 checking vision via subprocess"}
# {"timestamp": "2026-03-21T10:00:20.447817Z", "level": "info", "event": "Vision check (subprocess, transformers 5.x) for 'unsloth/qwen3.5-2b': model_type=qwen3_5, architectures=['Qwen3_5ForConditionalGeneration'], is_vision=True"}
# {"timestamp": "2026-03-21T10:00:20.613043Z", "level": "info", "event": "Model config result for unsloth/qwen3.5-2b: is_vision=True, is_embedding=False, audio_type=None, is_lora=False, max_position_embeddings=None"}
# {"timestamp": "2026-03-21T10:00:20.766252Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/config/unsloth/Qwen3.5-2B", "status_code": 200, "process_time_ms": 12234.17}
# {"timestamp": "2026-03-21T10:00:20.772089Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 2.87}
# {"timestamp": "2026-03-21T10:00:45.104588Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.04}
# {"timestamp": "2026-03-21T10:00:48.847278Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.15}
# {"timestamp": "2026-03-21T10:01:13.721621Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/upload", "status_code": 200, "process_time_ms": 50989.47}
# {"timestamp": "2026-03-21T10:01:14.319486Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 8.21}
# {"timestamp": "2026-03-21T10:01:14.320224Z", "level": "info", "event": "Checking format for dataset: /root/.unsloth/studio/assets/datasets/uploads/8d2881e7112243ccad9e426a66cdbcf1_chat_unsloth_chatml_with_topic.cleaned_rewritten_full.jsonl"}
# Generating train split: 0 examples [00:00, ? examples/s]
# {"timestamp": "2026-03-21T10:01:15.614453Z", "level": "info", "event": "Format check result: requires_mapping=True, format=unknown, is_image=False"}
# {"timestamp": "2026-03-21T10:01:15.620845Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 1305.87}
# {"timestamp": "2026-03-21T10:01:21.978383Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.2}
# {"timestamp": "2026-03-21T10:01:22.751460Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.44}
# {"timestamp": "2026-03-21T10:01:34.284272Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.28}
# {"timestamp": "2026-03-21T10:01:34.593258Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.04}
# {"timestamp": "2026-03-21T10:01:48.078177Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.92}
# {"timestamp": "2026-03-21T10:01:51.759047Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.92}
# {"timestamp": "2026-03-21T10:01:52.321638Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.34}
# {"timestamp": "2026-03-21T10:01:59.956512Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.1}
# {"timestamp": "2026-03-21T10:02:00.365584Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.32}
# {"timestamp": "2026-03-21T10:02:18.118782Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.08}
# {"timestamp": "2026-03-21T10:02:18.819353Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.97}
# {"timestamp": "2026-03-21T10:02:31.578861Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.54}
# {"timestamp": "2026-03-21T10:02:32.135469Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.78}
# {"timestamp": "2026-03-21T10:02:37.067295Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.03}
# {"timestamp": "2026-03-21T10:02:37.457690Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.11}
# {"timestamp": "2026-03-21T10:02:45.953134Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.26}
# {"timestamp": "2026-03-21T10:02:46.713073Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.57}
# {"timestamp": "2026-03-21T10:02:49.999209Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.97}
# {"timestamp": "2026-03-21T10:02:56.762488Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.18}
# {"timestamp": "2026-03-21T10:02:58.588895Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.71}
# {"timestamp": "2026-03-21T10:02:59.017955Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.52}
# {"timestamp": "2026-03-21T10:03:13.569381Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.96}
# {"timestamp": "2026-03-21T10:03:13.964479Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.8}
# {"timestamp": "2026-03-21T10:03:17.107266Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.71}
# {"timestamp": "2026-03-21T10:03:17.620693Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.22}
# {"timestamp": "2026-03-21T10:03:25.673951Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.94}
# {"timestamp": "2026-03-21T10:03:26.239254Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.31}
# {"timestamp": "2026-03-21T10:03:36.118314Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.44}
# {"timestamp": "2026-03-21T10:03:36.957443Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.89}
# {"timestamp": "2026-03-21T10:03:48.074534Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.97}
# {"timestamp": "2026-03-21T10:03:48.418252Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.09}
# {"timestamp": "2026-03-21T10:03:53.486771Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.47}
# {"timestamp": "2026-03-21T10:03:53.849662Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.17}
# {"timestamp": "2026-03-21T10:04:04.880065Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.96}
# {"timestamp": "2026-03-21T10:04:05.277077Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.34}
# {"timestamp": "2026-03-21T10:04:18.541078Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.1}
# {"timestamp": "2026-03-21T10:04:18.971000Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.12}
# {"timestamp": "2026-03-21T10:04:20.232101Z", "level": "info", "event": "Checking format for dataset: /root/.unsloth/studio/assets/datasets/uploads/8d2881e7112243ccad9e426a66cdbcf1_chat_unsloth_chatml_with_topic.cleaned_rewritten_full.jsonl"}
# {"timestamp": "2026-03-21T10:04:20.501897Z", "level": "info", "event": "Format check result: requires_mapping=False, format=chatml, is_image=False"}
# {"timestamp": "2026-03-21T10:04:20.505808Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 275.58}
# {"timestamp": "2026-03-21T10:04:34.638455Z", "level": "info", "event": "Starting training job with model: unsloth/Qwen3.5-2B"}
# {"timestamp": "2026-03-21T10:04:34.639483Z", "level": "info", "event": "Found local dataset file: /root/.unsloth/studio/assets/datasets/uploads/8d2881e7112243ccad9e426a66cdbcf1_chat_unsloth_chatml_with_topic.cleaned_rewritten_full.jsonl"}
# {"timestamp": "2026-03-21T10:04:34.645935Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-03-21T10:04:34.647689Z", "level": "info", "event": "InferenceOrchestrator initialized (subprocess mode)"}
# {"timestamp": "2026-03-21T10:04:34.649288Z", "level": "info", "event": "ExportOrchestrator initialized (subprocess mode)"}
# {"timestamp": "2026-03-21T10:04:34.679257Z", "level": "info", "event": "Training subprocess started (pid=25873)"}
# {"timestamp": "2026-03-21T10:04:34.688426Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/train/start", "status_code": 200, "process_time_ms": 52.52}
# {"timestamp": "2026-03-21T10:04:35.082675Z", "level": "info", "event": "Top GGUF models: ['unsloth/Qwen3.5-35B-A3B-GGUF', 'unsloth/Qwen3.5-9B-GGUF', 'unsloth/Qwen3.5-27B-GGUF', 'unsloth/Qwen3.5-122B-A10B-GGUF', 'unsloth/Qwen3.5-4B-GGUF', 'unsloth/Qwen3-Coder-Next-GGUF', 'unsloth/gpt-oss-20b-GGUF', 'unsloth/GLM-4.7-Flash-GGUF', 'unsloth/Qwen3.5-0.8B-GGUF', 'unsloth/Qwen3.5-2B-GGUF', 'unsloth/Nemotron-3-Nano-30B-A3B-GGUF', 'unsloth/Qwen3.5-397B-A17B-GGUF', 'unsloth/Qwen3-VL-4B-Instruct-GGUF', 'unsloth/LTX-2.3-GGUF', 'unsloth/Qwen3.5-35B-A3B-Experiments-GGUF', 'unsloth/GLM-4.6V-Flash-GGUF', 'unsloth/gemma-3-27b-it-GGUF', 'unsloth/Qwen3-Coder-30B-A3B-Instruct-GGUF', 'unsloth/gpt-oss-120b-GGUF', 'unsloth/gemma-3-12b-it-GGUF', 'unsloth/Qwen-Image-Edit-2511-GGUF', 'unsloth/Llama-3.2-1B-Instruct-GGUF', 'unsloth/Qwen3-0.6B-GGUF', 'unsloth/Qwen3-VL-30B-A3B-Instruct-GGUF', 'unsloth/MiniMax-M2.5-GGUF', 'unsloth/DeepSeek-R1-0528-Qwen3-8B-GGUF', 'unsloth/Qwen3-4B-Instruct-2507-GGUF', 'unsloth/gemma-3-4b-it-GGUF', 'unsloth/Qwen3-4B-GGUF', 'unsloth/Qwen2.5-VL-7B-Instruct-GGUF', 'unsloth/gemma-3-270m-it-GGUF', 'unsloth/DeepSeek-R1-Distill-Qwen-1.5B-GGUF', 'unsloth/Kimi-K2.5-GGUF', 'unsloth/FLUX.2-klein-9B-GGUF', 'unsloth/NVIDIA-Nemotron-3-Super-120B-A12B-GGUF']"}
# {"timestamp": "2026-03-21T10:04:35.083695Z", "level": "info", "event": "Top hub models: ['unsloth/GLM-4.7-Flash-FP8-Dynamic', 'unsloth/mistral-7b-v0.3-bnb-4bit', 'unsloth/Meta-Llama-3.1-8B-Instruct', 'unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit', 'unsloth/DeepSeek-OCR-2', 'unsloth/Qwen3-0.6B', 'unsloth/Llama-3.1-8B-Instruct', 'unsloth/Llama-3.2-1B-Instruct', 'unsloth/gpt-oss-20b', 'unsloth/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit', 'unsloth/gpt-oss-20b-unsloth-bnb-4bit', 'unsloth/Llama-3.2-3B-Instruct', 'unsloth/Qwen3-14B-unsloth-bnb-4bit', 'unsloth/Qwen2.5-7B-Instruct-bnb-4bit', 'unsloth/Qwen3-0.6B-unsloth-bnb-4bit', 'unsloth/Qwen3-4B-Base', 'unsloth/GLM-4.7-Flash', 'unsloth/Qwen2.5-7B', 'unsloth/Qwen2-7B', 'unsloth/Qwen2.5-3B-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen3.5-4B', 'unsloth/embeddinggemma-300m', 'unsloth/Qwen3-8B', 'unsloth/Qwen3-8B-unsloth-bnb-4bit', 'unsloth/Qwen3-4B', 'unsloth/Llama-3.2-1B-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen3-4B-bnb-4bit', 'unsloth/Pixtral-12B-2409-bnb-4bit', 'unsloth/Qwen3.5-9B', 'unsloth/DeepSeek-V3-0324-BF16', 'unsloth/Qwen2.5-7B-Instruct-unsloth-bnb-4bit', 'unsloth/Llama-3.2-3B-Instruct-unsloth-bnb-4bit', 'unsloth/llama-3-8b-bnb-4bit', 'unsloth/gpt-oss-120b-BF16', 'unsloth/Qwen3.5-2B', 'unsloth/Llama-3.2-1B', 'unsloth/gpt-oss-20b-BF16', 'unsloth/Qwen3-VL-4B-Instruct-unsloth-bnb-4bit', 'unsloth/Llama-3.2-3B-Instruct-bnb-4bit', 'unsloth/Qwen3-VL-2B-Instruct-unsloth-bnb-4bit']"}
# {"timestamp": "2026-03-21T10:04:38.655239Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/progress", "status_code": 200, "process_time_ms": 5.85}
# {"timestamp": "2026-03-21T10:07:46.503190Z", "level": "error", "event": "Training error: expected mat1 and mat2 to have the same dtype, but got: c10::BFloat16 != c10::Half"}
# {"timestamp": "2026-03-21T10:10:10.871810Z", "level": "info", "event": "Reset training state: clearing runtime + metric history"}
# {"timestamp": "2026-03-21T10:10:10.873018Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/train/reset", "status_code": 200, "process_time_ms": 2.61}
# {"timestamp": "2026-03-21T10:10:11.256539Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 1.85}
# {"timestamp": "2026-03-21T10:10:11.282107Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.08}
# {"timestamp": "2026-03-21T10:10:21.854721Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.94}
# {"timestamp": "2026-03-21T10:10:22.974868Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.03}
# {"timestamp": "2026-03-21T10:10:55.464529Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.05}
# {"timestamp": "2026-03-21T10:10:56.056944Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.95}
# {"timestamp": "2026-03-21T10:17:40.342913Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 3.97}
# {"timestamp": "2026-03-21T10:17:40.812808Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.0}
# {"timestamp": "2026-03-21T10:17:41.077467Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.52}
# {"timestamp": "2026-03-21T10:17:41.383503Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.11}
# {"timestamp": "2026-03-21T10:17:47.794451Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.95}
# {"timestamp": "2026-03-21T10:17:48.232398Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 3.06}
# {"timestamp": "2026-03-21T10:17:53.539215Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.94}
# {"timestamp": "2026-03-21T10:17:53.893596Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.43}
# {"timestamp": "2026-03-21T10:18:59.901282Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.48}
# {"timestamp": "2026-03-21T10:19:00.172048Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.17}
# {"timestamp": "2026-03-21T10:19:58.231396Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.0}
# {"timestamp": "2026-03-21T10:19:59.187992Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.63}
# {"timestamp": "2026-03-21T10:20:03.143155Z", "level": "info", "event": "Getting model config for: unsloth/qwen3.5-2b"}
# {"timestamp": "2026-03-21T10:20:03.153100Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-03-21T10:20:03.153649Z", "level": "info", "event": "Model 'unsloth/qwen3.5-2b' needs transformers 5.x \u2014 checking vision via subprocess"}
# {"timestamp": "2026-03-21T10:20:09.726818Z", "level": "info", "event": "Vision check (subprocess, transformers 5.x) for 'unsloth/qwen3.5-2b': model_type=qwen3_5, architectures=['Qwen3_5ForConditionalGeneration'], is_vision=True"}
# {"timestamp": "2026-03-21T10:20:10.151100Z", "level": "info", "event": "Model 'unsloth/qwen3.5-2b' needs transformers 5.x \u2014 checking vision via subprocess"}
# {"timestamp": "2026-03-21T10:20:16.231242Z", "level": "info", "event": "Vision check (subprocess, transformers 5.x) for 'unsloth/qwen3.5-2b': model_type=qwen3_5, architectures=['Qwen3_5ForConditionalGeneration'], is_vision=True"}
# {"timestamp": "2026-03-21T10:20:16.411409Z", "level": "info", "event": "Model config result for unsloth/qwen3.5-2b: is_vision=True, is_embedding=False, audio_type=None, is_lora=False, max_position_embeddings=None"}
# {"timestamp": "2026-03-21T10:20:16.581539Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/config/unsloth/Qwen3.5-2B", "status_code": 200, "process_time_ms": 13439.97}
# {"timestamp": "2026-03-21T10:20:25.534102Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.99}
# {"timestamp": "2026-03-21T10:20:25.821091Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.17}
# {"timestamp": "2026-03-21T10:20:32.004244Z", "level": "info", "event": "Checking format for dataset: /root/.unsloth/studio/assets/datasets/uploads/8d2881e7112243ccad9e426a66cdbcf1_chat_unsloth_chatml_with_topic.cleaned_rewritten_full.jsonl"}
# {"timestamp": "2026-03-21T10:20:32.282276Z", "level": "info", "event": "Format check result: requires_mapping=False, format=chatml, is_image=False"}
# {"timestamp": "2026-03-21T10:20:32.286519Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 284.11}
# {"timestamp": "2026-03-21T10:20:40.994858Z", "level": "info", "event": "Starting training job with model: unsloth/Qwen3.5-2B"}
# {"timestamp": "2026-03-21T10:20:40.995700Z", "level": "info", "event": "Found local dataset file: /root/.unsloth/studio/assets/datasets/uploads/8d2881e7112243ccad9e426a66cdbcf1_chat_unsloth_chatml_with_topic.cleaned_rewritten_full.jsonl"}
# {"timestamp": "2026-03-21T10:20:41.003251Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-03-21T10:20:41.007734Z", "level": "info", "event": "Training subprocess started (pid=30045)"}
# {"timestamp": "2026-03-21T10:20:41.010148Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/train/start", "status_code": 200, "process_time_ms": 16.65}
# {"timestamp": "2026-03-21T10:20:48.270602Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/progress", "status_code": 200, "process_time_ms": 2.18}
# {"timestamp": "2026-03-21T10:22:15.276604Z", "level": "error", "event": "Training error: expected mat1 and mat2 to have the same dtype, but got: c10::BFloat16 != c10::Half"}
# {"timestamp": "2026-03-21T10:23:10.591295Z", "level": "info", "event": "Reset training state: clearing runtime + metric history"}
# {"timestamp": "2026-03-21T10:23:10.592272Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/train/reset", "status_code": 200, "process_time_ms": 1.94}
# {"timestamp": "2026-03-21T10:23:10.939835Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 2.37}
# {"timestamp": "2026-03-21T10:23:10.987142Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 3.9}
# {"timestamp": "2026-03-21T10:23:17.324648Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.89}
# {"timestamp": "2026-03-21T10:23:24.304348Z", "level": "info", "event": "Checking format for dataset: /root/.unsloth/studio/assets/datasets/uploads/8d2881e7112243ccad9e426a66cdbcf1_chat_unsloth_chatml_with_topic.cleaned_rewritten_full.jsonl"}
# {"timestamp": "2026-03-21T10:23:24.671341Z", "level": "info", "event": "Format check result: requires_mapping=False, format=chatml, is_image=False"}
# {"timestamp": "2026-03-21T10:23:24.675967Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 374.5}
# {"timestamp": "2026-03-21T10:23:35.964899Z", "level": "info", "event": "Starting training job with model: unsloth/Qwen3.5-2B"}
# {"timestamp": "2026-03-21T10:23:35.966005Z", "level": "info", "event": "Found local dataset file: /root/.unsloth/studio/assets/datasets/uploads/8d2881e7112243ccad9e426a66cdbcf1_chat_unsloth_chatml_with_topic.cleaned_rewritten_full.jsonl"}
# {"timestamp": "2026-03-21T10:23:35.978108Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-03-21T10:23:35.983679Z", "level": "info", "event": "Training subprocess started (pid=30903)"}
# {"timestamp": "2026-03-21T10:23:35.984921Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/train/start", "status_code": 200, "process_time_ms": 22.62}
# {"timestamp": "2026-03-21T10:23:41.761475Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/progress", "status_code": 200, "process_time_ms": 1.86}
# {"timestamp": "2026-03-21T10:24:57.710363Z", "level": "error", "event": "Training error: expected mat1 and mat2 to have the same dtype, but got: c10::BFloat16 != c10::Half"}
# {"timestamp": "2026-03-21T10:25:27.523898Z", "level": "info", "event": "Reset training state: clearing runtime + metric history"}
# {"timestamp": "2026-03-21T10:25:27.524846Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/train/reset", "status_code": 200, "process_time_ms": 1.85}
# {"timestamp": "2026-03-21T10:25:28.037088Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 4.61}
# {"timestamp": "2026-03-21T10:25:28.040430Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 9.86}
# {"timestamp": "2026-03-21T10:26:10.657597Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.05}
# {"timestamp": "2026-03-21T10:26:11.173281Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.02}
# {"timestamp": "2026-03-21T10:26:14.813813Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.0}
# {"timestamp": "2026-03-21T10:26:26.871470Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.98}
# {"timestamp": "2026-03-21T10:27:12.169024Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.99}
# {"timestamp": "2026-03-21T10:27:57.063939Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.04}
# {"timestamp": "2026-03-21T10:28:02.327750Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.98}
# {"timestamp": "2026-03-21T10:28:03.788518Z", "level": "info", "event": "Checking format for dataset: /root/.unsloth/studio/assets/datasets/uploads/8d2881e7112243ccad9e426a66cdbcf1_chat_unsloth_chatml_with_topic.cleaned_rewritten_full.jsonl"}
# {"timestamp": "2026-03-21T10:28:04.047322Z", "level": "info", "event": "Format check result: requires_mapping=False, format=chatml, is_image=False"}
# {"timestamp": "2026-03-21T10:28:04.051554Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 264.83}
# {"timestamp": "2026-03-21T10:28:15.595221Z", "level": "info", "event": "Starting training job with model: unsloth/Qwen3.5-2B"}
# {"timestamp": "2026-03-21T10:28:15.596007Z", "level": "info", "event": "Found local dataset file: /root/.unsloth/studio/assets/datasets/uploads/8d2881e7112243ccad9e426a66cdbcf1_chat_unsloth_chatml_with_topic.cleaned_rewritten_full.jsonl"}
# {"timestamp": "2026-03-21T10:28:15.602982Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-03-21T10:28:15.606451Z", "level": "info", "event": "Training subprocess started (pid=32153)"}
# {"timestamp": "2026-03-21T10:28:15.608004Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/train/start", "status_code": 200, "process_time_ms": 13.88}
# {"timestamp": "2026-03-21T10:28:18.115551Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/progress", "status_code": 200, "process_time_ms": 1.98}

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other resources:
# 1. Looking to use Unsloth locally? Read our [Installation Guide](https://unsloth.ai/docs/get-started/install) for details on installing Unsloth on Windows, Docker, AMD, Intel GPUs.
# 2. Learn how to do Reinforcement Learning with our [RL Guide and notebooks](https://unsloth.ai/docs/get-started/reinforcement-learning-rl-guide).
# 3. Read our guides and notebooks for [Text-to-speech (TTS)](https://unsloth.ai/docs/basics/text-to-speech-tts-fine-tuning) and [vision](https://unsloth.ai/docs/basics/vision-fine-tuning) model support.
# 4. Explore our [LLM Tutorials Directory](https://unsloth.ai/docs/models/tutorials-how-to-fine-tune-and-run-llms) to find dedicated guides for each model.
# 5. Need help with Inference? Read our [Inference & Deployment page](https://unsloth.ai/docs/basics/inference-and-deployment) for details on using vLLM, llama.cpp, Ollama etc.
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
#
#   <b>This notebook is licensed <a href="https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0">AGPL-3.0</a></b>
# </div>
