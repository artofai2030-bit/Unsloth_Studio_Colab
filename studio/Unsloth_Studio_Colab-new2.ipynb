# %% [markdown]
# <a href="https://colab.research.google.com/github/artofai2030-bit/Unsloth_Studio_Colab/blob/main/studio/Unsloth_Studio_Colab-new2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth Studio on your local device, follow [our guide](https://unsloth.ai/docs/new/unsloth-studio/install). Unsloth Studio is licensed [AGPL-3.0](https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0).
#
# ### Unsloth Studio
#
# Train and run open models with [**Unsloth Studio**](https://unsloth.ai/docs/new/unsloth-studio/start). NEW! Installation should now only take 2 mins!
#
#
# We are actively working on making Unsloth Studio install on Colab T4 GPUs faster.
#
# [Features](https://unsloth.ai/docs/new/unsloth-studio#features) • [Quickstart](https://unsloth.ai/docs/new/unsloth-studio/start) • [Data Recipes](https://unsloth.ai/docs/new/unsloth-studio/data-recipe) • [Studio Chat](https://unsloth.ai/docs/new/unsloth-studio/chat) • [Export](https://unsloth.ai/docs/new/unsloth-studio/export)

# %% [markdown]
# <p align="left"><img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/studio%20github%20landscape%20colab%20display.png" width="600"></p>

# %% [markdown]
# ### Setup: Clone repo and run setup

# %%
# !git clone --depth 1 --branch main https://github.com/unslothai/unsloth.git
# %cd /content/unsloth
# !chmod +x studio/setup.sh && ./studio/setup.sh
# Out:
# Cloning into 'unsloth'...
# remote: Enumerating objects: 1037, done.
# remote: Counting objects: 100% (1037/1037), done.
# remote: Compressing objects: 100% (863/863), done.
# remote: Total 1037 (delta 178), reused 687 (delta 154), pack-reused 0 (from 0)
# Receiving objects: 100% (1037/1037), 31.11 MiB | 21.51 MiB/s, done.
# Resolving deltas: 100% (178/178), done.
# /content/unsloth
# ╔══════════════════════════════════════╗
# ║     Unsloth Studio Update Script     ║
# ╚══════════════════════════════════════╝
# ✅ Node v20.19.0 and npm 10.8.2 detected in Colab.
#    Upgrading npm to latest...
# ✅ Node v20.19.0 | npm 11.12.1
#    Installing bun (faster frontend package installs)...
#    bun installed (1.3.11)
#    Using bun for package install (faster)
# ✅ Frontend built to frontend/dist
#    Colab detected, installing Studio backend dependencies...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.5/69.5 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 340.4/340.4 kB 20.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 104.7 MB/s eta 0:00:00
# ✅ Studio backend dependencies installed into system Python
# [====================] 11/11  finalizing
# ✅ Python dependencies installed
#
#    Pre-installing transformers 5.x for newer model support...
# ✅ Transformers 5.x pre-installed to /root/.unsloth/studio/.venv_t5/
#
# Resolved llama.cpp release tag: b8508
#
# Installing prebuilt llama.cpp bundle (preferred path)...
# [llama-prebuilt] no existing llama.cpp install detected at /root/.unsloth/llama.cpp; performing fresh prebuilt install
# [llama-prebuilt] published_release: repo=unslothai/llama.cpp
# [llama-prebuilt] published_release: tag=b8508
# [llama-prebuilt] published_release: manifest=llama-prebuilt-manifest.json
# [llama-prebuilt] published_release: upstream_tag=b8508
# [llama-prebuilt] torch_cuda_preference: selected runtime_line=cuda12 from torch.version.cuda=12.8
# [llama-prebuilt] linux_cuda_selection: release=b8508
# [llama-prebuilt] linux_cuda_selection: detected_sms=75
# [llama-prebuilt] linux_cuda_selection: detected_runtime_lines=cuda12
# [llama-prebuilt] linux_cuda_selection: driver_runtime_lines=cuda13,cuda12
# [llama-prebuilt] linux_cuda_selection: compatible_runtime_lines=cuda12
# [llama-prebuilt] linux_cuda_selection: runtime_dirs cuda13=none
# [llama-prebuilt] linux_cuda_selection: runtime_dirs cuda12=/usr/local/cuda-12.8/targets/x86_64-linux/lib,/usr/local/lib/python3.12/dist-packages/nvidia/cuda_runtime/lib,/usr/local/lib/python3.12/dist-packages/nvidia/cublas/lib
# [llama-prebuilt] linux_cuda_selection: published_assets=app-b8508-linux-x64-cuda12-newer.tar.gz,app-b8508-linux-x64-cuda12-older.tar.gz,app-b8508-linux-x64-cuda12-portable.tar.gz,app-b8508-linux-x64-cuda13-newer.tar.gz,app-b8508-linux-x64-cuda13-older.tar.gz,app-b8508-linux-x64-cuda13-portable.tar.gz
# [llama-prebuilt] linux_cuda_selection: torch_preferred_runtime_line=cuda12 reordered_attempts=cuda12
# [llama-prebuilt] linux_cuda_selection: accept app-b8508-linux-x64-cuda12-older.tar.gz runtime_line=cuda12 coverage_class=older coverage=70-89 supported=70,75,80,86,89
# [llama-prebuilt] linux_cuda_selection: reject app-b8508-linux-x64-cuda12-newer.tar.gz runtime_line=cuda12 coverage_class=newer coverage=86-120 supported=86,89,90,100,120 reasons=missing_sms=75 out_of_range_sms=75
# [llama-prebuilt] linux_cuda_selection: accept app-b8508-linux-x64-cuda12-portable.tar.gz runtime_line=cuda12 coverage_class=portable coverage=70-120 supported=70,75,80,86,89,90,100,120
# [llama-prebuilt] linux_cuda_selection: attempt_order=app-b8508-linux-x64-cuda12-older.tar.gz,app-b8508-linux-x64-cuda12-portable.tar.gz
# [llama-prebuilt] selected app-b8508-linux-x64-cuda12-older.tar.gz (published) for Linux x86_64
# [llama-prebuilt] downloading tiny GGUF validation model
# [llama-prebuilt] created install staging dir /root/.unsloth/.staging/llama.cpp.staging-kv8pj1df
# [llama-prebuilt] hydrating upstream llama.cpp source for b8508 into /root/.unsloth/.staging/llama.cpp.staging-kv8pj1df
# [llama-prebuilt] downloading llama.cpp source tree for upstream tag b8508
# [llama-prebuilt] verified llama.cpp source tree for b8508 sha256=a41d2c532c44ff6fc79da2a3d306d6e4f654e32e88fe886e496a55c338774f9f
# [llama-prebuilt] overlaying prebuilt bundle app-b8508-linux-x64-cuda12-older.tar.gz into /root/.unsloth/.staging/llama.cpp.staging-kv8pj1df
# [llama-prebuilt] downloading app-b8508-linux-x64-cuda12-older.tar.gz from published release
# [llama-prebuilt] verified prebuilt archive app-b8508-linux-x64-cuda12-older.tar.gz sha256=d40fb39a6f215459fa6cddcabf6b8661617caac500cff9961fdc91120176f7cc
# [llama-prebuilt] staged prebuilt validation succeeded for app-b8508-linux-x64-cuda12-older.tar.gz
# [llama-prebuilt] activating staged install /root/.unsloth/.staging/llama.cpp.staging-kv8pj1df -> /root/.unsloth/llama.cpp
# [llama-prebuilt] activated staged install at /root/.unsloth/llama.cpp
# [llama-prebuilt] confirming activated install tree at /root/.unsloth/llama.cpp
# [llama-prebuilt] activated install tree confirmed at /root/.unsloth/llama.cpp
# ✅ Prebuilt llama.cpp installed and validated
#
# ╔══════════════════════════════════════╗
# ║          Update Complete!            ║
# ╠══════════════════════════════════════╣
# ║ Unsloth Studio is ready to start     ║
# ║ in your Colab notebook!              ║
# ║                                      ║
# ║ from colab import start              ║
# ║ start()                              ║
# ╚══════════════════════════════════════╝

# %% [markdown]
# ### Start Unsloth Studio

# %%
import sys, time
sys.path.insert(0, "/content/unsloth/studio/backend")
from colab import start
start()
# Out:
# {"timestamp": "2026-03-27T09:39:12.261000Z", "level": "info", "event": "\ud83e\udda5 Starting Unsloth Studio..."}
# {"timestamp": "2026-03-27T09:39:12.262262Z", "level": "info", "event": "   Loading backend..."}
# {"timestamp": "2026-03-27T09:39:12.262780Z", "level": "info", "event": "   Starting server..."}
# INFO:     Started server process [915]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8889 (Press CTRL+C to quit)
# Hardware detected: CUDA — Tesla T4
# {"timestamp": "2026-03-27T09:39:12.387700Z", "level": "info", "event": "Pre-caching helper GGUF: unsloth/Qwen3.5-4B-GGUF/Qwen3.5-4B-UD-Q4_K_XL.gguf"}
# {"timestamp": "2026-03-27T09:39:12.468226Z", "level": "info", "event": "Helper GGUF cached: 1 file(s)"}
# {"timestamp": "2026-03-27T09:39:15.275965Z", "level": "info", "event": "   Server started!"}
#     <div style="display: inline-block; padding: 20px; background: #ffffff; border: 2px solid #000000;
#                 border-radius: 12px; margin: 10px 0; font-family: system-ui, -apple-system, sans-serif;">
#         <h2 style="color: #000000; margin: 0 0 12px 0; font-size: 26px; font-weight: 800;
#                    display: flex; align-items: center; gap: 12px;">
#             <img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/unsloth-gem.png"
#                  height="48" style="display:block;">
#             Unsloth Studio is Ready!
#         </h2>
#         <a href="https://8888-gpu-t4-s-kkb-usw4a2-2zx7ie6zgfva7-a.us-west4-2.prod.colab.dev" target="_blank"
#            style="display: inline-flex; align-items: center; gap: 10px; padding: 14px 28px;
#                   background: #000000; color: white; text-decoration: none; border-radius: 8px;
#                   font-weight: 800; font-size: 16px;">
#             <svg xmlns="http://www.w3.org/2000/svg" width="18" height="18" viewBox="0 0 24 24" fill="white"><polygon points="5,3 19,12 5,21"/></svg>
#             Open Unsloth Studio
#         </a>
#         <p style="color: #333333; margin: 16px 0 0 0; font-size: 13px; font-family: monospace;">
#             https://8888-gpu-...
#         </p>
#     </div>

# %%
from google.colab import output
output.serve_kernel_port_as_iframe(8888, height = 1200, width = "100%")
for _ in range(10000): time.sleep(300), print("=", end = "")
# Out:
# {"timestamp": "2026-03-27T11:04:20.251569Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 2.26}
# {"timestamp": "2026-03-27T11:04:35.911359Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 0.78}
# {"timestamp": "2026-03-27T11:04:36.276354Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.93}
# {"timestamp": "2026-03-27T11:04:36.819910Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.81}
# {"timestamp": "2026-03-27T11:04:37.858681Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.34}
# {"timestamp": "2026-03-27T11:04:38.234644Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/v1/chat/completions", "status_code": 200, "process_time_ms": 31673.09}
# {"timestamp": "2026-03-27T11:04:39.177747Z", "level": "error", "event": "Error during GGUF streaming: llama-server returned 400: {\"error\":{\"code\":400,\"message\":\"request (251591 tokens) exceeds the available context size (4096 tokens), try increasing it\",\"type\":\"exceed_context_size_error\",\"n_prompt_tokens\":251591,\"n_ctx\":4096}}", "exc_info": true}
# {"timestamp": "2026-03-27T11:06:03.895303Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/v1/chat/completions", "status_code": 200, "process_time_ms": 2.4}
# {"timestamp": "2026-03-27T11:06:12.364839Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/v1/chat/completions", "status_code": 200, "process_time_ms": 1.77}
# {"timestamp": "2026-03-27T11:07:03.662818Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/v1/chat/completions", "status_code": 200, "process_time_ms": 1.99}
# {"timestamp": "2026-03-27T11:08:11.701751Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/v1/chat/completions", "status_code": 200, "process_time_ms": 31391.31}
# {"timestamp": "2026-03-27T11:08:12.238533Z", "level": "error", "event": "Error during GGUF streaming: llama-server returned 400: {\"error\":{\"code\":400,\"message\":\"request (220870 tokens) exceeds the available context size (4096 tokens), try increasing it\",\"type\":\"exceed_context_size_error\",\"n_prompt_tokens\":220870,\"n_ctx\":4096}}", "exc_info": true}
# ={"timestamp": "2026-03-27T11:09:27.638910Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 5.74}
# {"timestamp": "2026-03-27T11:09:27.699310Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.39}
# {"timestamp": "2026-03-27T11:09:27.714841Z", "level": "info", "event": "Found 1 trained LoRA adapters in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-03-27T11:09:27.715607Z", "level": "info", "event": "Detected base model from adapter_config.json: unsloth/Qwen3-4B-Instruct-2507"}
# {"timestamp": "2026-03-27T11:09:27.717418Z", "level": "info", "event": "Found 1 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-03-27T11:09:27.724075Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-03-27T11:09:27.729390Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 15.66}
# {"timestamp": "2026-03-27T11:09:27.730233Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 16.43}
# {"timestamp": "2026-03-27T11:09:28.690200Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 2.05}
# {"timestamp": "2026-03-27T11:09:28.706671Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 6.86}
# {"timestamp": "2026-03-27T11:10:09.493108Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.03}
# {"timestamp": "2026-03-27T11:10:09.753076Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.95}
# {"timestamp": "2026-03-27T11:10:16.336685Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 2.01}
# {"timestamp": "2026-03-27T11:10:16.382282Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.61}
# {"timestamp": "2026-03-27T11:10:16.416042Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.04}
# {"timestamp": "2026-03-27T11:10:16.927072Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 5.81}
# {"timestamp": "2026-03-27T11:10:16.934928Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-03-27T11:10:16.940440Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 11.04}
# {"timestamp": "2026-03-27T11:10:16.947755Z", "level": "info", "event": "Found 1 trained LoRA adapters in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-03-27T11:10:16.948703Z", "level": "info", "event": "Detected base model from adapter_config.json: unsloth/Qwen3-4B-Instruct-2507"}
# {"timestamp": "2026-03-27T11:10:16.950651Z", "level": "info", "event": "Found 1 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-03-27T11:10:16.951826Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 5.23}
# {"timestamp": "2026-03-27T11:10:20.814922Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 6.4}
# {"timestamp": "2026-03-27T11:10:20.850292Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.1}
# {"timestamp": "2026-03-27T11:10:23.065605Z", "level": "info", "event": "Found 1 trained LoRA adapters in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-03-27T11:10:23.066695Z", "level": "info", "event": "Detected base model from adapter_config.json: unsloth/Qwen3-4B-Instruct-2507"}
# {"timestamp": "2026-03-27T11:10:23.067925Z", "level": "info", "event": "Found 1 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-03-27T11:10:23.069559Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 5.18}
# {"timestamp": "2026-03-27T11:10:23.077988Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-03-27T11:10:23.083276Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 12.75}
# {"timestamp": "2026-03-27T11:10:30.170532Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 5.01}
# {"timestamp": "2026-03-27T11:10:30.537182Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.74}
# {"timestamp": "2026-03-27T11:10:33.235907Z", "level": "info", "event": "Found 1 trained LoRA adapters in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-03-27T11:10:33.237050Z", "level": "info", "event": "Detected base model from adapter_config.json: unsloth/Qwen3-4B-Instruct-2507"}
# {"timestamp": "2026-03-27T11:10:33.239113Z", "level": "info", "event": "Found 1 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-03-27T11:10:33.239955Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 5.54}
# {"timestamp": "2026-03-27T11:10:33.308324Z", "level": "info", "event": "Found 1 training runs in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-03-27T11:10:33.309147Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/checkpoints", "status_code": 200, "process_time_ms": 2.45}
# {"timestamp": "2026-03-27T11:10:33.318745Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-03-27T11:10:33.324097Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 9.3}
# {"timestamp": "2026-03-27T11:10:35.668538Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 4.03}
# {"timestamp": "2026-03-27T11:10:37.071493Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.38}
# {"timestamp": "2026-03-27T11:10:39.194726Z", "level": "info", "event": "Found 1 trained LoRA adapters in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-03-27T11:10:39.195735Z", "level": "info", "event": "Detected base model from adapter_config.json: unsloth/Qwen3-4B-Instruct-2507"}
# {"timestamp": "2026-03-27T11:10:39.197659Z", "level": "info", "event": "Found 1 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-03-27T11:10:39.198751Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 5.52}
# {"timestamp": "2026-03-27T11:10:39.957363Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-03-27T11:10:39.966638Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 15.93}
# {"timestamp": "2026-03-27T11:12:36.856237Z", "level": "info", "event": "Found 1 training runs in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-03-27T11:12:36.859178Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/checkpoints", "status_code": 200, "process_time_ms": 6.01}
# {"timestamp": "2026-03-27T11:12:36.860828Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 7.31}
# {"timestamp": "2026-03-27T11:12:37.331512Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 2.74}
# {"timestamp": "2026-03-27T11:12:37.345528Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 3.21}
# {"timestamp": "2026-03-27T11:13:08.843898Z", "level": "info", "event": "Getting model config for: unsloth/qwen3.5-2b"}
# {"timestamp": "2026-03-27T11:13:08.851180Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-03-27T11:13:08.851945Z", "level": "info", "event": "Model 'unsloth/qwen3.5-2b' needs transformers 5.x \u2014 checking vision via subprocess"}
# {"timestamp": "2026-03-27T11:13:20.772193Z", "level": "info", "event": "Vision check (subprocess, transformers 5.x) for 'unsloth/qwen3.5-2b': model_type=qwen3_5, architectures=['Qwen3_5ForConditionalGeneration'], is_vision=True"}
# {"timestamp": "2026-03-27T11:13:21.709673Z", "level": "info", "event": "Model 'unsloth/qwen3.5-2b' needs transformers 5.x \u2014 checking vision via subprocess"}
# {"timestamp": "2026-03-27T11:13:28.829319Z", "level": "info", "event": "Vision check (subprocess, transformers 5.x) for 'unsloth/qwen3.5-2b': model_type=qwen3_5, architectures=['Qwen3_5ForConditionalGeneration'], is_vision=True"}
# {"timestamp": "2026-03-27T11:13:29.017842Z", "level": "info", "event": "Model config result for unsloth/qwen3.5-2b: is_vision=True, is_embedding=False, audio_type=None, is_lora=False, max_position_embeddings=None"}
# {"timestamp": "2026-03-27T11:13:29.197585Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/config/unsloth/Qwen3.5-2B", "status_code": 200, "process_time_ms": 20355.61}
# {"timestamp": "2026-03-27T11:13:50.191629Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.34}
# ={"timestamp": "2026-03-27T11:15:05.719926Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 3.01}
# {"timestamp": "2026-03-27T11:15:06.042702Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 5.24}
# {"timestamp": "2026-03-27T11:15:11.012406Z", "level": "info", "event": "Checking format for dataset: /root/.unsloth/studio/assets/datasets/uploads/348b0806ddcb4a96bb657d73130969ae_chat_unsloth_chatml_with_topic.colab_prompt_completion.jsonl"}
# {"timestamp": "2026-03-27T11:15:11.309420Z", "level": "info", "event": "Format check result: requires_mapping=False, format=custom_heuristic, is_image=False"}
# {"timestamp": "2026-03-27T11:15:11.313712Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 303.05}
# {"timestamp": "2026-03-27T11:15:12.352071Z", "level": "info", "event": "Starting training job with model: unsloth/Qwen3.5-2B"}
# {"timestamp": "2026-03-27T11:15:12.353205Z", "level": "info", "event": "Found local dataset file: /root/.unsloth/studio/assets/datasets/uploads/348b0806ddcb4a96bb657d73130969ae_chat_unsloth_chatml_with_topic.colab_prompt_completion.jsonl"}
# {"timestamp": "2026-03-27T11:15:12.360661Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-03-27T11:15:12.363659Z", "level": "info", "event": "Training subprocess started (pid=30743)"}
# {"timestamp": "2026-03-27T11:15:12.379707Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/train/start", "status_code": 200, "process_time_ms": 29.62}
# {"timestamp": "2026-03-27T11:15:14.175844Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/progress", "status_code": 200, "process_time_ms": 2.39}
# {"timestamp": "2026-03-27T11:19:00.683540Z", "level": "error", "event": "Training error: expected mat1 and mat2 to have the same dtype, but got: c10::BFloat16 != c10::Half"}
# ====={"timestamp": "2026-03-27T11:39:49.883227Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/refresh", "status_code": 200, "process_time_ms": 3.42}
# ={"timestamp": "2026-03-27T11:48:32.766967Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 13.3}
# {"timestamp": "2026-03-27T11:48:32.774168Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 4.83}
# {"timestamp": "2026-03-27T11:48:39.867280Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.94}
# ={"timestamp": "2026-03-27T11:51:33.156581Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.94}
# {"timestamp": "2026-03-27T11:51:34.067325Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.08}
# {"timestamp": "2026-03-27T11:54:07.547260Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.01}
# {"timestamp": "2026-03-27T11:54:08.163829Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.53}
# =={"timestamp": "2026-03-27T12:00:22.587745Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.22}
# {"timestamp": "2026-03-27T12:00:22.893195Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.21}
# ={"timestamp": "2026-03-27T12:05:17.773842Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.08}
# {"timestamp": "2026-03-27T12:05:18.860609Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.1}
# {"timestamp": "2026-03-27T12:05:35.392469Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.84}
# {"timestamp": "2026-03-27T12:05:35.783559Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.22}
# {"timestamp": "2026-03-27T12:06:03.399034Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.2}
# {"timestamp": "2026-03-27T12:06:03.645578Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.3}
# {"timestamp": "2026-03-27T12:06:33.268834Z", "level": "info", "event": "Getting model config for: qwen/qwen3-4b"}
# {"timestamp": "2026-03-27T12:06:33.280438Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# config.json:   0%|          | 0.00/726 [00:00<?, ?B/s]
# {"timestamp": "2026-03-27T12:06:35.101709Z", "level": "info", "event": "Model config result for qwen/qwen3-4b: is_vision=False, is_embedding=False, audio_type=None, is_lora=False, max_position_embeddings=40960"}
# {"timestamp": "2026-03-27T12:06:35.274916Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/config/Qwen/Qwen3-4B", "status_code": 200, "process_time_ms": 2007.57}
# {"timestamp": "2026-03-27T12:07:41.058258Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.7}
# {"timestamp": "2026-03-27T12:07:41.298822Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.22}
# {"timestamp": "2026-03-27T12:08:10.677031Z", "level": "info", "event": "Getting model config for: unsloth/qwen3-4b-instruct-2507-unsloth-bnb-4bit"}
# {"timestamp": "2026-03-27T12:08:10.683753Z", "level": "info", "event": "Loaded model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/qwen/unsloth_Qwen3-4B-Instruct-2507.yaml (via mapping)"}
# {"timestamp": "2026-03-27T12:08:12.405750Z", "level": "info", "event": "Model config result for unsloth/qwen3-4b-instruct-2507-unsloth-bnb-4bit: is_vision=False, is_embedding=False, audio_type=None, is_lora=False, max_position_embeddings=262144"}
# {"timestamp": "2026-03-27T12:08:12.580415Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/config/unsloth/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit", "status_code": 200, "process_time_ms": 1904.48}
# {"timestamp": "2026-03-27T12:08:19.535318Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.19}
# {"timestamp": "2026-03-27T12:08:19.828631Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 4.17}
# {"timestamp": "2026-03-27T12:08:26.357690Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 3.68}
# {"timestamp": "2026-03-27T12:08:26.756575Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.75}
# ={"timestamp": "2026-03-27T12:09:21.684222Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.33}
# {"timestamp": "2026-03-27T12:13:05.243534Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.2}
# {"timestamp": "2026-03-27T12:13:05.518810Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.49}
# ={"timestamp": "2026-03-27T12:16:05.001880Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.09}
# {"timestamp": "2026-03-27T12:16:05.332584Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.91}
# {"timestamp": "2026-03-27T12:16:27.454621Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.0}
# {"timestamp": "2026-03-27T12:16:27.716562Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.9}
# ={"timestamp": "2026-03-27T12:23:15.656938Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.57}
# {"timestamp": "2026-03-27T12:23:15.959065Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 5.16}
# {"timestamp": "2026-03-27T12:23:26.451716Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.89}
# {"timestamp": "2026-03-27T12:23:31.950503Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 3.04}
# ={"timestamp": "2026-03-27T12:24:52.318164Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 5.25}
# {"timestamp": "2026-03-27T12:24:52.853818Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.75}
# {"timestamp": "2026-03-27T12:24:58.342848Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.26}
# {"timestamp": "2026-03-27T12:25:05.786068Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.93}
# {"timestamp": "2026-03-27T12:25:42.677658Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/upload", "status_code": 200, "process_time_ms": 42749.99}
# {"timestamp": "2026-03-27T12:25:43.045290Z", "level": "info", "event": "Checking format for dataset: /root/.unsloth/studio/assets/datasets/uploads/39125c36974445c58575fc18d8e283cf_chat_unsloth_qwen3_4b_prompt_completion_text.jsonl"}
# Generating train split: 0 examples [00:00, ? examples/s]
# {"timestamp": "2026-03-27T12:25:43.374611Z", "level": "info", "event": "Format check result: requires_mapping=False, format=custom_heuristic, is_image=False"}
# {"timestamp": "2026-03-27T12:25:43.376890Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 333.64}
# {"timestamp": "2026-03-27T12:26:45.509207Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 4.41}
# {"timestamp": "2026-03-27T12:26:46.330222Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.11}
# {"timestamp": "2026-03-27T12:26:49.105563Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.01}
# {"timestamp": "2026-03-27T12:27:09.353916Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.95}
# {"timestamp": "2026-03-27T12:27:09.646494Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.0}
# {"timestamp": "2026-03-27T12:27:14.681703Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.15}
# {"timestamp": "2026-03-27T12:27:14.961710Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.39}
# {"timestamp": "2026-03-27T12:27:19.589424Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.65}
# {"timestamp": "2026-03-27T12:27:20.050930Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.62}
# {"timestamp": "2026-03-27T12:27:33.788182Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.88}
# {"timestamp": "2026-03-27T12:27:34.058722Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.91}
# {"timestamp": "2026-03-27T12:28:13.290372Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.46}
# {"timestamp": "2026-03-27T12:28:13.626773Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.01}
# {"timestamp": "2026-03-27T12:28:21.094420Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.96}
# {"timestamp": "2026-03-27T12:28:21.359766Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.35}
# {"timestamp": "2026-03-27T12:28:31.261428Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.95}
# {"timestamp": "2026-03-27T12:28:31.517515Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.08}
# {"timestamp": "2026-03-27T12:28:42.611316Z", "level": "info", "event": "Checking format for dataset: /root/.unsloth/studio/assets/datasets/uploads/39125c36974445c58575fc18d8e283cf_chat_unsloth_qwen3_4b_prompt_completion_text.jsonl"}
# {"timestamp": "2026-03-27T12:28:42.849558Z", "level": "info", "event": "Format check result: requires_mapping=False, format=custom_heuristic, is_image=False"}
# {"timestamp": "2026-03-27T12:28:42.851509Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 242.63}
# Repo card metadata block was not found. Setting CardData to empty.
# WARNING:huggingface_hub.repocard:Repo card metadata block was not found. Setting CardData to empty.
# {"timestamp": "2026-03-27T12:29:07.021435Z", "level": "info", "event": "Fetched dataset card: 1431 chars, 0 metadata fields"}
# {"timestamp": "2026-03-27T12:29:07.032930Z", "level": "info", "event": "Killed orphaned llama-server process (pid=25013)"}
# {"timestamp": "2026-03-27T12:29:07.033380Z", "level": "info", "event": "Loading advisor model: unsloth/Qwen3.5-4B-GGUF (UD-Q4_K_XL)"}
# {"timestamp": "2026-03-27T12:29:07.242519Z", "level": "info", "event": "GGUF download: 2.7 GB needed, 162.8 GB free on disk"}
# {"timestamp": "2026-03-27T12:29:07.262771Z", "level": "info", "event": "Resolving GGUF: unsloth/Qwen3.5-4B-GGUF/Qwen3.5-4B-UD-Q4_K_XL.gguf"}
# {"timestamp": "2026-03-27T12:29:07.397228Z", "level": "info", "event": "GGUF resolved from cache: /root/.cache/huggingface/hub/models--unsloth--Qwen3.5-4B-GGUF/snapshots/e87f176479d0855a907a41277aca2f8ee7a09523/Qwen3.5-4B-UD-Q4_K_XL.gguf"}
# {"timestamp": "2026-03-27T12:29:07.708575Z", "level": "info", "event": "GGUF metadata: context_length=262144"}
# {"timestamp": "2026-03-27T12:29:07.709699Z", "level": "info", "event": "GGUF metadata: chat_template=7816 chars"}
# {"timestamp": "2026-03-27T12:29:07.710204Z", "level": "info", "event": "GGUF metadata: model supports reasoning (enable_thinking)"}
# {"timestamp": "2026-03-27T12:29:07.710717Z", "level": "info", "event": "GGUF metadata: model supports tool calling"}
# {"timestamp": "2026-03-27T12:29:07.742026Z", "level": "info", "event": "GGUF size: 2.7 GB, GPUs free: [(0, 14690)], selected: [0], fit: False"}
# {"timestamp": "2026-03-27T12:29:07.742716Z", "level": "info", "event": "Reasoning model: enable_thinking=False by default"}
# {"timestamp": "2026-03-27T12:29:07.743323Z", "level": "info", "event": "Starting llama-server: /root/.unsloth/llama.cpp/llama-server -m /root/.cache/huggingface/hub/models--unsloth--Qwen3.5-4B-GGUF/snapshots/e87f176479d0855a907a41277aca2f8ee7a09523/Qwen3.5-4B-UD-Q4_K_XL.gguf --port 32933 -c 2048 --parallel 1 --flash-attn on -ngl -1 --jinja --chat-template-kwargs {\"enable_thinking\": false}"}
# ={"timestamp": "2026-03-27T12:29:22.749368Z", "level": "info", "event": "llama-server ready on port 32933 for model 'advisor:unsloth/Qwen3.5-4B-GGUF:UD-Q4_K_XL'"}
# {"timestamp": "2026-03-27T12:29:22.750279Z", "level": "info", "event": "Advisor model loaded in 15.7s"}
# config.json: 0.00B [00:00, ?B/s]
# {"timestamp": "2026-03-27T12:29:22.878447Z", "level": "info", "event": "Pass 1: Classifying dataset..."}
# {"timestamp": "2026-03-27T12:29:22.879867Z", "level": "info", "event": "Advisor request: enable_thinking=False (per-request override)"}
# {"timestamp": "2026-03-27T12:29:26.688312Z", "level": "info", "event": "Pass 1 done (3.8s): {'dataset_type': 'question_answering', 'is_conversational': False, 'needs_conversion': True, 'description': 'A dataset containing Russian FAQ questions and answers regarding government services and accreditation procedures.', 'task_description': 'The task involves taking a specific FAQ question as input and generating a corresponding answer as output.'}"}
# {"timestamp": "2026-03-27T12:29:26.689045Z", "level": "info", "event": "Pass 2: Mapping columns to roles..."}
# {"timestamp": "2026-03-27T12:29:26.689923Z", "level": "info", "event": "Advisor request: enable_thinking=False (per-request override)"}
# {"timestamp": "2026-03-27T12:29:31.095380Z", "level": "info", "event": "Pass 2 done (4.4s): {'column_roles': {'prompt': 'user', 'completion': 'assistant'}, 'label_mapping': None, 'notes': \"The 'prompt' column contains the input question/context provided to the model, so it is assigned to 'user'. The 'completion' column contains the generated answer/response, which is the target output the model should learn to produce, so it is assigned to 'assistant'.\"}"}
# {"timestamp": "2026-03-27T12:29:31.097256Z", "level": "info", "event": "Pass 3: Generating system prompt..."}
# {"timestamp": "2026-03-27T12:29:31.098535Z", "level": "info", "event": "Advisor request: enable_thinking=False (per-request override)"}
# {"timestamp": "2026-03-27T12:29:33.621224Z", "level": "info", "event": "Pass 3 done (2.5s): You are an expert FAQ assistant tasked with answering specific questions based on provided information. You will receive a user prompt containing a frequently asked question, and your goal is to gener"}
# {"timestamp": "2026-03-27T12:29:33.622215Z", "level": "info", "event": "Advisor complete (26.6s): type=question_answering, mapping={'prompt': 'user', 'completion': 'assistant'}, sys_prompt=True, label_map=False"}
# {"timestamp": "2026-03-27T12:29:35.442646Z", "level": "info", "event": "Unloaded GGUF model: advisor:unsloth/Qwen3.5-4B-GGUF:UD-Q4_K_XL"}
# {"timestamp": "2026-03-27T12:29:35.443462Z", "level": "info", "event": "Advisor model unloaded"}
# {"timestamp": "2026-03-27T12:29:35.445187Z", "level": "info", "event": "Conversion advisor succeeded: type=question_answering"}
# {"timestamp": "2026-03-27T12:29:35.447604Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/ai-assist-mapping", "status_code": 200, "process_time_ms": 28436.69}
# {"timestamp": "2026-03-27T12:30:34.286148Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 8.43}
# {"timestamp": "2026-03-27T12:30:57.850356Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.98}
# {"timestamp": "2026-03-27T12:30:59.325398Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 3.42}
# {"timestamp": "2026-03-27T12:31:19.912753Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.01}
# {"timestamp": "2026-03-27T12:31:20.173357Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.58}
# {"timestamp": "2026-03-27T12:32:16.937653Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.04}
# {"timestamp": "2026-03-27T12:32:17.230344Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.22}
# {"timestamp": "2026-03-27T12:32:19.059786Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.96}
# {"timestamp": "2026-03-27T12:32:19.332853Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.93}
# ={"timestamp": "2026-03-27T12:36:32.442869Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.24}
# {"timestamp": "2026-03-27T12:36:33.322363Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.03}
# {"timestamp": "2026-03-27T12:36:44.018588Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.98}
# {"timestamp": "2026-03-27T12:37:19.340267Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/upload", "status_code": 200, "process_time_ms": 32954.8}
# {"timestamp": "2026-03-27T12:37:19.849694Z", "level": "info", "event": "Checking format for dataset: /root/.unsloth/studio/assets/datasets/uploads/7d940ad45c7b4f55ad0644f4da016a41_chat_unsloth_system_user_assistant.jsonl"}
# Generating train split: 0 examples [00:00, ? examples/s]
# {"timestamp": "2026-03-27T12:37:20.137681Z", "level": "info", "event": "Format check result: requires_mapping=False, format=custom_heuristic, is_image=False"}
# {"timestamp": "2026-03-27T12:37:20.141951Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 295.13}
# {"timestamp": "2026-03-27T12:38:36.651389Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.22}
# {"timestamp": "2026-03-27T12:38:46.870726Z", "level": "info", "event": "Checking format for dataset: /root/.unsloth/studio/assets/datasets/uploads/7d940ad45c7b4f55ad0644f4da016a41_chat_unsloth_system_user_assistant.jsonl"}
# {"timestamp": "2026-03-27T12:38:47.086172Z", "level": "info", "event": "Format check result: requires_mapping=False, format=custom_heuristic, is_image=False"}
# {"timestamp": "2026-03-27T12:38:47.088885Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 220.54}
# ={"timestamp": "2026-03-27T12:39:39.545515Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.28}
# {"timestamp": "2026-03-27T12:39:46.360130Z", "level": "info", "event": "Checking format for dataset: /root/.unsloth/studio/assets/datasets/uploads/7d940ad45c7b4f55ad0644f4da016a41_chat_unsloth_system_user_assistant.jsonl"}
# {"timestamp": "2026-03-27T12:39:46.587165Z", "level": "info", "event": "Format check result: requires_mapping=False, format=custom_heuristic, is_image=False"}
# {"timestamp": "2026-03-27T12:39:46.590088Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 233.07}
# {"timestamp": "2026-03-27T12:39:47.431379Z", "level": "info", "event": "Starting training job with model: unsloth/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit"}
# {"timestamp": "2026-03-27T12:39:47.433339Z", "level": "info", "event": "Found local dataset file: /root/.unsloth/studio/assets/datasets/uploads/7d940ad45c7b4f55ad0644f4da016a41_chat_unsloth_system_user_assistant.jsonl"}
# {"timestamp": "2026-03-27T12:39:47.444507Z", "level": "info", "event": "Loaded model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/qwen/unsloth_Qwen3-4B-Instruct-2507.yaml (via mapping)"}
# {"timestamp": "2026-03-27T12:39:47.448847Z", "level": "info", "event": "Training subprocess started (pid=52144)"}
# {"timestamp": "2026-03-27T12:39:47.467575Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/train/start", "status_code": 200, "process_time_ms": 39.63}
# {"timestamp": "2026-03-27T12:39:56.749469Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/refresh", "status_code": 200, "process_time_ms": 5.43}
# {"timestamp": "2026-03-27T12:39:58.551646Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/refresh", "status_code": 200, "process_time_ms": 4.05}
# {"timestamp": "2026-03-27T12:39:58.935519Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/refresh", "status_code": 200, "process_time_ms": 5.13}
# {"timestamp": "2026-03-27T12:39:58.944503Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/refresh", "status_code": 200, "process_time_ms": 9.28}
# {"timestamp": "2026-03-27T12:39:58.963434Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/refresh", "status_code": 200, "process_time_ms": 6.39}
# {"timestamp": "2026-03-27T12:39:59.282838Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/refresh", "status_code": 200, "process_time_ms": 8.75}
# {"timestamp": "2026-03-27T12:39:59.738028Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/progress", "status_code": 200, "process_time_ms": 1.56}
# ============{"timestamp": "2026-03-27T13:40:53.905733Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/refresh", "status_code": 200, "process_time_ms": 3.54}
# {"timestamp": "2026-03-27T13:40:54.005803Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/refresh", "status_code": 200, "process_time_ms": 2.06}
# ={"timestamp": "2026-03-27T13:44:37.582562Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 5.46}
# {"timestamp": "2026-03-27T13:44:37.599320Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 8.74}
# {"timestamp": "2026-03-27T13:44:37.603620Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.06}
# {"timestamp": "2026-03-27T13:44:38.248481Z", "level": "info", "event": "Found 2 training runs in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-03-27T13:44:38.249638Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/checkpoints", "status_code": 200, "process_time_ms": 76.17}
# {"timestamp": "2026-03-27T13:45:34.358935Z", "level": "info", "event": "Spawning fresh export subprocess for '/root/.unsloth/studio/outputs/unsloth_Qwen3-4B-Instruct-2507-unsloth-bnb-4bit_1774615405/checkpoint-360'"}
# {"timestamp": "2026-03-27T13:45:34.365237Z", "level": "info", "event": "Export subprocess started (pid=68688)"}
# {"timestamp": "2026-03-27T13:45:35.599255Z", "level": "info", "event": "Export subprocess status: Importing Unsloth..."}
# {"timestamp": "2026-03-27T13:46:15.665883Z", "level": "info", "event": "Export subprocess status: Loading checkpoint: /root/.unsloth/studio/outputs/unsloth_Qwen3-4B-Instruct-2507-unsloth-bnb-4bit_1774615405/checkpoint-360"}
# {"timestamp": "2026-03-27T13:46:39.392090Z", "level": "info", "event": "Checkpoint '/root/.unsloth/studio/outputs/unsloth_Qwen3-4B-Instruct-2507-unsloth-bnb-4bit_1774615405/checkpoint-360' loaded in subprocess"}
# {"timestamp": "2026-03-27T13:46:39.393941Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/export/load-checkpoint", "status_code": 200, "process_time_ms": 65037.26}
# ===={"timestamp": "2026-03-27T14:05:35.735477Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/export/export/gguf", "status_code": 200, "process_time_ms": 1135777.41}
# {"timestamp": "2026-03-27T14:05:35.764249Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 19.95}
# ===
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_915/3552804093.py in <cell line: 0>()
#       1 from google.colab import output
#       2 output.serve_kernel_port_as_iframe(8888, height = 1200, width = "100%")
# ----> 3 for _ in range(10000): time.sleep(300), print("=", end = "")
#
# KeyboardInterrupt:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !mkdir -p /content/drive/MyDrive/unsloth_exports
# !rsync -avh /root/.unsloth/studio/exports/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit-finetune-gguf/ /content/drive/MyDrive/unsloth_exports/
# Out:
# sending incremental file list
# ./
# model/
# model/model-00002-of-00002.safetensors
# {"timestamp": "2026-03-27T14:27:43.605974Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/v1/chat/completions", "status_code": 200, "process_time_ms": 4.52}
# {"timestamp": "2026-03-27T14:27:43.749730Z", "level": "error", "event": "Error during GGUF tool streaming: Lost connection to llama-server\nTraceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_transports/default.py\", line 101, in map_httpcore_exceptions\n    yield\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_transports/default.py\", line 250, in handle_request\n    resp = self._pool.handle_request(req)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection_pool.py\", line 256, in handle_request\n    raise exc from None\n  File \"/usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection_pool.py\", line 236, in handle_request\n    response = connection.handle_request(\n               ^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection.py\", line 101, in handle_request\n    raise exc\n  File \"/usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection.py\", line 78, in handle_request\n    stream = self._connect(request)\n             ^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection.py\", line 124, in _connect\n    stream = self._network_backend.connect_tcp(**kwargs)\n             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpcore/_backends/sync.py\", line 207, in connect_tcp\n    with map_exceptions(exc_map):\n         ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/contextlib.py\", line 158, in __exit__\n    self.gen.throw(value)\n  File \"/usr/local/lib/python3.12/dist-packages/httpcore/_exceptions.py\", line 14, in map_exceptions\n    raise to_exc(exc) from exc\nhttpcore.ConnectError: [Errno 111] Connection refused\n\nThe above exception was the direct cause of the following exception:\n\nTraceback (most recent call last):\n  File \"/content/unsloth/studio/backend/core/inference/llama_cpp.py\", line 1710, in generate_chat_completion_with_tools\n    resp = client.post(url, json = payload)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_client.py\", line 1144, in post\n    return self.request(\n           ^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_client.py\", line 825, in request\n    return self.send(request, auth=auth, follow_redirects=follow_redirects)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_client.py\", line 914, in send\n    response = self._send_handling_auth(\n               ^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_client.py\", line 942, in _send_handling_auth\n    response = self._send_handling_redirects(\n               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_client.py\", line 979, in _send_handling_redirects\n    response = self._send_single_request(request)\n               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_client.py\", line 1014, in _send_single_request\n    response = transport.handle_request(request)\n               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_transports/default.py\", line 249, in handle_request\n    with map_httpcore_exceptions():\n         ^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/contextlib.py\", line 158, in __exit__\n    self.gen.throw(value)\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_transports/default.py\", line 118, in map_httpcore_exceptions\n    raise mapped_exc(message) from exc\nhttpx.ConnectError: [Errno 111] Connection refused\n\nDuring handling of the above exception, another exception occurred:\n\nTraceback (most recent call last):\n  File \"/content/unsloth/studio/backend/routes/inference.py\", line 1115, i ...
# {"timestamp": "2026-03-27T14:27:56.531388Z", "level": "info", "event": "Detected base model from adapter_config.json: unsloth/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit"}
# {"timestamp": "2026-03-27T14:27:56.532854Z", "level": "info", "event": "Auto-detected local LoRA adapter at '/root/.unsloth/studio/outputs/unsloth_Qwen3-4B-Instruct-2507-unsloth-bnb-4bit_1774615405' (base: unsloth/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit)"}
# {"timestamp": "2026-03-27T14:27:56.534025Z", "level": "info", "event": "Detected base model from adapter_config.json: unsloth/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit"}
# {"timestamp": "2026-03-27T14:27:57.030999Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/inference/validate", "status_code": 200, "process_time_ms": 505.49}
# {"timestamp": "2026-03-27T14:27:57.041402Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.35}
# {"timestamp": "2026-03-27T14:27:57.302525Z", "level": "info", "event": "Unloaded GGUF model: /root/.unsloth/studio/exports/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit-finetune-gguf/qwen3-4b-instruct-2507.Q4_K_M.gguf"}
# {"timestamp": "2026-03-27T14:27:57.303431Z", "level": "info", "event": "Unloaded GGUF model: /root/.unsloth/studio/exports/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit-finetune-gguf/qwen3-4b-instruct-2507.Q4_K_M.gguf"}
# {"timestamp": "2026-03-27T14:27:57.304377Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/inference/unload", "status_code": 200, "process_time_ms": 3.74}
# {"timestamp": "2026-03-27T14:27:57.714775Z", "level": "info", "event": "Detected base model from adapter_config.json: unsloth/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit"}
# {"timestamp": "2026-03-27T14:27:57.718015Z", "level": "info", "event": "Auto-detected local LoRA adapter at '/root/.unsloth/studio/outputs/unsloth_Qwen3-4B-Instruct-2507-unsloth-bnb-4bit_1774615405' (base: unsloth/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit)"}
# {"timestamp": "2026-03-27T14:27:57.718933Z", "level": "info", "event": "Detected base model from adapter_config.json: unsloth/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit"}
# {"timestamp": "2026-03-27T14:27:57.817739Z", "level": "info", "event": "Training method: qlora, load_in_4bit=True"}
# {"timestamp": "2026-03-27T14:27:58.598518Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.66}
# {"timestamp": "2026-03-27T14:28:00.597295Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.39}
# {"timestamp": "2026-03-27T14:28:02.628513Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 6.96}
# {"timestamp": "2026-03-27T14:28:04.599112Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 3.14}
# {"timestamp": "2026-03-27T14:28:06.613917Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 7.24}
# {"timestamp": "2026-03-27T14:28:08.595643Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.83}
# {"timestamp": "2026-03-27T14:28:08.637208Z", "level": "warning", "event": "Inference subprocess did not exit gracefully, terminating"}
# {"timestamp": "2026-03-27T14:28:08.949296Z", "level": "info", "event": "Inference subprocess shut down"}
# {"timestamp": "2026-03-27T14:28:08.952953Z", "level": "info", "event": "Spawning fresh inference subprocess for '/root/.unsloth/studio/outputs/unsloth_Qwen3-4B-Instruct-2507-unsloth-bnb-4bit_1774615405' (transformers 4.x)"}
# {"timestamp": "2026-03-27T14:28:08.961383Z", "level": "info", "event": "Inference subprocess started (pid=82308)"}
# {"timestamp": "2026-03-27T14:28:10.590532Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.86}
# {"timestamp": "2026-03-27T14:28:12.590681Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 3.73}
# {"timestamp": "2026-03-27T14:28:13.360455Z", "level": "info", "event": "Subprocess status: Importing Unsloth..."}
# {"timestamp": "2026-03-27T14:28:14.512500Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.39}
# {"timestamp": "2026-03-27T14:28:16.543712Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.65}
# {"timestamp": "2026-03-27T14:28:18.780494Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 3.59}
# {"timestamp": "2026-03-27T14:28:20.517996Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.83}
# {"timestamp": "2026-03-27T14:28:22.522468Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.54}
# {"timestamp": "2026-03-27T14:28:24.519268Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.91}
# {"timestamp": "2026-03-27T14:28:26.542754Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.86}
# {"timestamp": "2026-03-27T14:28:29.147010Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.53}
# {"timestamp": "2026-03-27T14:28:30.520678Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.73}
# {"timestamp": "2026-03-27T14:28:32.798337Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 3.8}
# {"timestamp": "2026-03-27T14:28:34.523393Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 4.29}
# {"timestamp": "2026-03-27T14:28:36.538020Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.29}
# {"timestamp": "2026-03-27T14:28:38.532799Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.52}
# {"timestamp": "2026-03-27T14:28:40.527532Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.69}
# {"timestamp": "2026-03-27T14:28:42.522066Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.5}
# {"timestamp": "2026-03-27T14:28:44.545498Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.51}
# {"timestamp": "2026-03-27T14:28:46.557559Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 5.64}
# {"timestamp": "2026-03-27T14:28:48.828720Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 4.79}
# {"timestamp": "2026-03-27T14:28:50.529314Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.75}
# {"timestamp": "2026-03-27T14:28:52.519361Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.58}
# {"timestamp": "2026-03-27T14:28:54.523059Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.56}
# {"timestamp": "2026-03-27T14:28:56.541981Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.45}
# {"timestamp": "2026-03-27T14:28:59.093169Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.23}
# {"timestamp": "2026-03-27T14:29:00.523438Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.3}
# {"timestamp": "2026-03-27T14:29:02.562576Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 4.77}
# {"timestamp": "2026-03-27T14:29:04.527396Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.85}
# {"timestamp": "2026-03-27T14:29:06.546875Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 4.21}
# {"timestamp": "2026-03-27T14:29:08.537254Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.3}
# {"timestamp": "2026-03-27T14:29:10.524678Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.91}
# {"timestamp": "2026-03-27T14:29:12.526670Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.68}
# {"timestamp": "2026-03-27T14:29:14.567375Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.12}
# {"timestamp": "2026-03-27T14:29:16.544361Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.9}
# {"timestamp": "2026-03-27T14:29:18.555664Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.84}
# {"timestamp": "2026-03-27T14:29:20.523687Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.43}
# {"timestamp": "2026-03-27T14:29:22.541571Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.16}
# {"timestamp": "2026-03-27T14:29:24.520105Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.48}
# {"timestamp": "2026-03-27T14:29:26.535392Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.68}
# {"timestamp": "2026-03-27T14:29:28.545350Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 3.78}
# {"timestamp": "2026-03-27T14:29:30.545109Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.93}
# {"timestamp": "2026-03-27T14:29:32.562420Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.75}
# {"timestamp": "2026-03-27T14:29:34.517823Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.15}
# {"timestamp": "2026-03-27T14:29:36.531086Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 6.48}
# {"timestamp": "2026-03-27T14:29:38.523567Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.66}
# {"timestamp": "2026-03-27T14:29:40.532625Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 3.72}
# {"timestamp": "2026-03-27T14:29:42.785159Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 3.16}
# {"timestamp": "2026-03-27T14:29:44.522614Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.7}
# {"timestamp": "2026-03-27T14:29:46.523554Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.88}
# {"timestamp": "2026-03-27T14:29:48.530328Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 4.82}
# {"timestamp": "2026-03-27T14:29:50.543054Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.63}
# {"timestamp": "2026-03-27T14:29:52.519277Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 3.61}
# {"timestamp": "2026-03-27T14:29:54.789957Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.02}
# {"timestamp": "2026-03-27T14:29:56.593268Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.6}
# {"timestamp": "2026-03-27T14:29:58.612825Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.83}
# {"timestamp": "2026-03-27T14:30:00.595491Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 3.22}
# {"timestamp": "2026-03-27T14:30:02.599010Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.75}
# {"timestamp": "2026-03-27T14:30:04.652670Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.95}
# {"timestamp": "2026-03-27T14:30:06.615894Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.55}
# {"timestamp": "2026-03-27T14:30:13.806821Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 6.58}
# {"timestamp": "2026-03-27T14:30:14.110978Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 3.73}
# {"timestamp": "2026-03-27T14:30:14.800104Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 3.13}
# {"timestamp": "2026-03-27T14:30:15.055894Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 3.85}
# {"timestamp": "2026-03-27T14:30:16.608881Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.04}
# {"timestamp": "2026-03-27T14:30:18.614555Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 3.61}
# {"timestamp": "2026-03-27T14:30:19.952746Z", "level": "info", "event": "Subprocess status: Loading model..."}
# {"timestamp": "2026-03-27T14:30:20.627853Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.93}
# {"timestamp": "2026-03-27T14:30:22.610943Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.93}
# {"timestamp": "2026-03-27T14:30:24.609514Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.04}
# {"timestamp": "2026-03-27T14:30:26.601072Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 4.76}
# {"timestamp": "2026-03-27T14:30:28.611496Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 4.5}
# {"timestamp": "2026-03-27T14:30:30.616254Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.7}
# {"timestamp": "2026-03-27T14:30:32.605068Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.35}
# {"timestamp": "2026-03-27T14:30:34.598697Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.58}
# {"timestamp": "2026-03-27T14:30:36.595330Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.38}
# {"timestamp": "2026-03-27T14:30:38.606488Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.57}
# {"timestamp": "2026-03-27T14:30:40.599160Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.89}
# model/model.safetensors.index.json
# model/special_tokens_map.json
# model/tokenizer.json
# model/tokenizer_config.json
# model/vocab.json
# {"timestamp": "2026-03-27T14:30:42.609506Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.9}
# model/.cache/
# model/.cache/huggingface/
# model/.cache/huggingface/.gitignore
# model/.cache/huggingface/download/
# model/.cache/huggingface/download/model-00001-of-00002.safetensors.metadata
# model/.cache/huggingface/download/model-00002-of-00002.safetensors.metadata
# model/.cache/huggingface/download/model.safetensors.index.json.metadata
# model_gguf/
# model_gguf/qwen3-4b-instruct-2507.F16.gguf
# {"timestamp": "2026-03-27T14:30:44.571349Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.63}
# {"timestamp": "2026-03-27T14:30:46.525888Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.38}
# {"timestamp": "2026-03-27T14:30:48.517521Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.54}
# {"timestamp": "2026-03-27T14:30:50.526440Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.56}
# {"timestamp": "2026-03-27T14:30:52.526403Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.51}
# {"timestamp": "2026-03-27T14:30:54.529586Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 5.0}
# {"timestamp": "2026-03-27T14:30:56.532697Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 3.25}
# {"timestamp": "2026-03-27T14:30:58.539888Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.67}
# {"timestamp": "2026-03-27T14:31:04.984099Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 4.7}
# {"timestamp": "2026-03-27T14:31:05.304447Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.23}
# {"timestamp": "2026-03-27T14:31:05.538997Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.58}
# {"timestamp": "2026-03-27T14:31:06.549977Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.93}
# {"timestamp": "2026-03-27T14:31:08.782019Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.43}
# {"timestamp": "2026-03-27T14:31:08.965537Z", "level": "error", "event": "Error loading model: Timeout waiting for 'loaded' response after 180s", "exc_info": true}
# {"timestamp": "2026-03-27T14:31:08.966701Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/inference/load", "status_code": 500, "process_time_ms": 191254.12}
# {"timestamp": "2026-03-27T14:31:09.249698Z", "level": "info", "event": "Detected local GGUF model: /root/.unsloth/studio/exports/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit-finetune-gguf/qwen3-4b-instruct-2507.Q4_K_M.gguf"}
# {"timestamp": "2026-03-27T14:31:09.791770Z", "level": "info", "event": "GGUF metadata: context_length=262144"}
# {"timestamp": "2026-03-27T14:31:09.792877Z", "level": "info", "event": "GGUF metadata: chat_template=4040 chars"}
# {"timestamp": "2026-03-27T14:31:09.793309Z", "level": "info", "event": "GGUF metadata: model supports tool calling"}
# {"timestamp": "2026-03-27T14:31:09.838778Z", "level": "info", "event": "GGUF size: 2.3 GB, GPUs free: [(0, 10860)], selected: [0], fit: False"}
# {"timestamp": "2026-03-27T14:31:09.839695Z", "level": "info", "event": "Starting llama-server: /root/.unsloth/llama.cpp/llama-server -m /root/.unsloth/studio/exports/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit-finetune-gguf/qwen3-4b-instruct-2507.Q4_K_M.gguf --port 58371 -c 32768 --parallel 1 --flash-attn on -ngl -1 --jinja"}
# {"timestamp": "2026-03-27T14:31:10.552896Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 4.81}
# {"timestamp": "2026-03-27T14:31:12.552013Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 6.43}
# {"timestamp": "2026-03-27T14:31:14.523089Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.53}
# {"timestamp": "2026-03-27T14:31:16.520021Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.32}
# {"timestamp": "2026-03-27T14:31:18.533960Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.42}
# {"timestamp": "2026-03-27T14:31:20.566487Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.56}
# {"timestamp": "2026-03-27T14:31:22.528043Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 12.33}
# {"timestamp": "2026-03-27T14:31:24.535799Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.8}
# {"timestamp": "2026-03-27T14:31:32.451897Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.63}
# {"timestamp": "2026-03-27T14:31:32.752700Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.62}
# {"timestamp": "2026-03-27T14:31:33.363445Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.7}
# {"timestamp": "2026-03-27T14:31:33.689574Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.83}
# {"timestamp": "2026-03-27T14:31:34.529599Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.35}
# {"timestamp": "2026-03-27T14:31:36.524759Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.11}
# {"timestamp": "2026-03-27T14:31:38.536908Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 7.87}
# {"timestamp": "2026-03-27T14:31:40.549141Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.55}
# {"timestamp": "2026-03-27T14:31:40.581465Z", "level": "info", "event": "llama-server ready on port 58371 for model '/root/.unsloth/studio/exports/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit-finetune-gguf/qwen3-4b-instruct-2507.Q4_K_M.gguf'"}
# {"timestamp": "2026-03-27T14:31:40.582397Z", "level": "info", "event": "Loaded GGUF model via llama-server: /root/.unsloth/studio/exports/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit-finetune-gguf/qwen3-4b-instruct-2507.Q4_K_M.gguf"}
# {"timestamp": "2026-03-27T14:31:40.851975Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-03-27T14:31:40.892719Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/inference/load", "status_code": 200, "process_time_ms": 31646.57}
# {"timestamp": "2026-03-27T14:31:41.215905Z", "level": "info", "event": "Found 2 trained LoRA adapters in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-03-27T14:31:41.218357Z", "level": "info", "event": "Detected base model from adapter_config.json: unsloth/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit"}
# {"timestamp": "2026-03-27T14:31:41.223308Z", "level": "info", "event": "Detected base model from adapter_config.json: unsloth/Qwen3-4B-Instruct-2507"}
# {"timestamp": "2026-03-27T14:31:41.232935Z", "level": "info", "event": "Found 2 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-03-27T14:31:41.235715Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 45.51}
# {"timestamp": "2026-03-27T14:31:41.261815Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-03-27T14:31:41.284650Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 45.3}
# {"timestamp": "2026-03-27T14:31:41.286812Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 47.34}
# {"timestamp": "2026-03-27T14:31:57.528785Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/v1/chat/completions", "status_code": 200, "process_time_ms": 11.5}
# {"timestamp": "2026-03-27T14:34:04.325796Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/v1/chat/completions", "status_code": 200, "process_time_ms": 36.23}
# {"timestamp": "2026-03-27T14:34:42.947536Z", "level": "info", "event": "Unloaded GGUF model: /root/.unsloth/studio/exports/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit-finetune-gguf/qwen3-4b-instruct-2507.Q4_K_M.gguf"}
# {"timestamp": "2026-03-27T14:34:42.949550Z", "level": "info", "event": "Unloaded GGUF model: /root/.unsloth/studio/exports/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit-finetune-gguf/qwen3-4b-instruct-2507.Q4_K_M.gguf"}
# {"timestamp": "2026-03-27T14:34:42.950690Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/inference/unload", "status_code": 200, "process_time_ms": 3066.86}
# {"timestamp": "2026-03-27T14:34:43.432174Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 24.56}
# {"timestamp": "2026-03-27T14:34:43.443472Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 5.8}
# {"timestamp": "2026-03-27T14:34:43.456198Z", "level": "info", "event": "Found 2 trained LoRA adapters in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-03-27T14:34:43.460606Z", "level": "info", "event": "Detected base model from adapter_config.json: unsloth/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit"}
# {"timestamp": "2026-03-27T14:34:43.464403Z", "level": "info", "event": "Detected base model from adapter_config.json: unsloth/Qwen3-4B-Instruct-2507"}
# {"timestamp": "2026-03-27T14:34:43.470227Z", "level": "info", "event": "Found 2 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-03-27T14:34:43.471507Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 21.27}
# {"timestamp": "2026-03-27T14:35:06.859101Z", "level": "info", "event": "Detected local GGUF model: /root/.unsloth/studio/exports/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit-finetune-gguf/qwen3-4b-instruct-2507.Q4_K_M.gguf"}
# {"timestamp": "2026-03-27T14:35:06.977080Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/inference/validate", "status_code": 200, "process_time_ms": 136.09}
# {"timestamp": "2026-03-27T14:35:07.327569Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.69}
# model_gguf/qwen3-4b-instruct-2507.Q4_K_M.gguf
# {"timestamp": "2026-03-27T14:35:11.931318Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.65}
# {"timestamp": "2026-03-27T14:35:12.909509Z", "level": "info", "event": "Detected local GGUF model: /root/.unsloth/studio/exports/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit-finetune-gguf/qwen3-4b-instruct-2507.Q4_K_M.gguf"}
# {"timestamp": "2026-03-27T14:35:13.132671Z", "level": "info", "event": "GGUF metadata: context_length=262144"}
# {"timestamp": "2026-03-27T14:35:13.211513Z", "level": "info", "event": "GGUF metadata: chat_template=4040 chars"}
# {"timestamp": "2026-03-27T14:35:13.212477Z", "level": "info", "event": "GGUF metadata: model supports tool calling"}
# {"timestamp": "2026-03-27T14:35:13.242485Z", "level": "info", "event": "GGUF size: 2.3 GB, GPUs free: [(0, 11082)], selected: [0], fit: False"}
# {"timestamp": "2026-03-27T14:35:13.244614Z", "level": "info", "event": "Starting llama-server: /root/.unsloth/llama.cpp/llama-server -m /root/.unsloth/studio/exports/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit-finetune-gguf/qwen3-4b-instruct-2507.Q4_K_M.gguf --port 56839 -c 32768 --parallel 1 --flash-attn on -ngl -1 --jinja"}
# {"timestamp": "2026-03-27T14:35:14.662666Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.95}
# {"timestamp": "2026-03-27T14:35:15.572219Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.61}
# {"timestamp": "2026-03-27T14:35:15.818696Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 6.95}
# {"timestamp": "2026-03-27T14:35:16.854704Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.55}
# {"timestamp": "2026-03-27T14:35:17.623207Z", "level": "info", "event": "llama-server ready on port 56839 for model '/root/.unsloth/studio/exports/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit-finetune-gguf/qwen3-4b-instruct-2507.Q4_K_M.gguf'"}
# {"timestamp": "2026-03-27T14:35:17.625246Z", "level": "info", "event": "Loaded GGUF model via llama-server: /root/.unsloth/studio/exports/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit-finetune-gguf/qwen3-4b-instruct-2507.Q4_K_M.gguf"}
# {"timestamp": "2026-03-27T14:35:17.719794Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-03-27T14:35:17.727726Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/inference/load", "status_code": 200, "process_time_ms": 4819.83}
# {"timestamp": "2026-03-27T14:35:19.488580Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.44}
# {"timestamp": "2026-03-27T14:35:19.718441Z", "level": "info", "event": "Found 2 trained LoRA adapters in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-03-27T14:35:19.719719Z", "level": "info", "event": "Detected base model from adapter_config.json: unsloth/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit"}
# {"timestamp": "2026-03-27T14:35:19.730641Z", "level": "info", "event": "Detected base model from adapter_config.json: unsloth/Qwen3-4B-Instruct-2507"}
# {"timestamp": "2026-03-27T14:35:19.732400Z", "level": "info", "event": "Found 2 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-03-27T14:35:19.742378Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 30.69}
# {"timestamp": "2026-03-27T14:35:19.744191Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 32.36}
# {"timestamp": "2026-03-27T14:35:19.759812Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-03-27T14:35:19.768555Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 22.67}
# {"timestamp": "2026-03-27T14:35:29.443902Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/v1/chat/completions", "status_code": 200, "process_time_ms": 2.26}
# {"timestamp": "2026-03-27T14:35:38.733898Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/v1/chat/completions", "status_code": 200, "process_time_ms": 2.35}
# {"timestamp": "2026-03-27T14:35:52.518418Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/v1/chat/completions", "status_code": 200, "process_time_ms": 4.42}
# {"timestamp": "2026-03-27T14:36:11.647816Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/v1/chat/completions", "status_code": 200, "process_time_ms": 2.98}
# {"timestamp": "2026-03-27T14:36:27.561703Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/v1/chat/completions", "status_code": 200, "process_time_ms": 2.3}
# {"timestamp": "2026-03-27T14:36:38.611425Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/v1/chat/completions", "status_code": 200, "process_time_ms": 2.34}

# %%
# !mkdir -p /content/drive/MyDrive/unsloth_outputs
# !rsync -avh /root/.unsloth/studio/outputs/unsloth_Qwen3-4B-Instruct-2507-unsloth-bnb-4bit_1774615405/ /content/drive/MyDrive/unsloth_outputs/
# Out:
# sending incremental file list
# ./
# README.md
# adapter_config.json
# adapter_model.safetensors
# added_tokens.json
# chat_template.jinja
# merges.txt
# special_tokens_map.json
# tokenizer.json
# tokenizer_config.json
# training_args.bin
# vocab.json
# checkpoint-120/
# checkpoint-120/README.md
# checkpoint-120/adapter_config.json
# checkpoint-120/adapter_model.safetensors
# checkpoint-120/added_tokens.json
# checkpoint-120/chat_template.jinja
# checkpoint-120/merges.txt
# checkpoint-120/optimizer.pt
# checkpoint-120/rng_state.pth
# checkpoint-120/scaler.pt
# checkpoint-120/scheduler.pt
# checkpoint-120/special_tokens_map.json
# checkpoint-120/tokenizer.json
# checkpoint-120/tokenizer_config.json
# checkpoint-120/trainer_state.json
# checkpoint-120/training_args.bin
# checkpoint-120/vocab.json
# checkpoint-150/
# checkpoint-150/README.md
# checkpoint-150/adapter_config.json
# checkpoint-150/adapter_model.safetensors
# checkpoint-150/added_tokens.json
# checkpoint-150/chat_template.jinja
# checkpoint-150/merges.txt
# checkpoint-150/optimizer.pt
# checkpoint-150/rng_state.pth
# checkpoint-150/scaler.pt
# checkpoint-150/scheduler.pt
# checkpoint-150/special_tokens_map.json
# checkpoint-150/tokenizer.json
# checkpoint-150/tokenizer_config.json
# checkpoint-150/trainer_state.json
# checkpoint-150/training_args.bin
# checkpoint-150/vocab.json
# checkpoint-180/
# checkpoint-180/README.md
# checkpoint-180/adapter_config.json
# checkpoint-180/adapter_model.safetensors
# checkpoint-180/added_tokens.json
# checkpoint-180/chat_template.jinja
# checkpoint-180/merges.txt
# checkpoint-180/optimizer.pt
# checkpoint-180/rng_state.pth
# checkpoint-180/scaler.pt
# checkpoint-180/scheduler.pt
# checkpoint-180/special_tokens_map.json
# checkpoint-180/tokenizer.json
# checkpoint-180/tokenizer_config.json
# checkpoint-180/trainer_state.json
# checkpoint-180/training_args.bin
# checkpoint-180/vocab.json
# checkpoint-210/
# checkpoint-210/README.md
# checkpoint-210/adapter_config.json
# checkpoint-210/adapter_model.safetensors
# checkpoint-210/added_tokens.json
# checkpoint-210/chat_template.jinja
# checkpoint-210/merges.txt
# checkpoint-210/optimizer.pt
# checkpoint-210/rng_state.pth
# checkpoint-210/scaler.pt
# checkpoint-210/scheduler.pt
# checkpoint-210/special_tokens_map.json
# checkpoint-210/tokenizer.json
# checkpoint-210/tokenizer_config.json
# checkpoint-210/trainer_state.json
# checkpoint-210/training_args.bin
# checkpoint-210/vocab.json
# checkpoint-240/
# checkpoint-240/README.md
# checkpoint-240/adapter_config.json
# checkpoint-240/adapter_model.safetensors
# checkpoint-240/added_tokens.json
# checkpoint-240/chat_template.jinja
# checkpoint-240/merges.txt
# checkpoint-240/optimizer.pt
# checkpoint-240/rng_state.pth
# checkpoint-240/scaler.pt
# checkpoint-240/scheduler.pt
# checkpoint-240/special_tokens_map.json
# checkpoint-240/tokenizer.json
# checkpoint-240/tokenizer_config.json
# checkpoint-240/trainer_state.json
# checkpoint-240/training_args.bin
# checkpoint-240/vocab.json
# checkpoint-270/
# checkpoint-270/README.md
# checkpoint-270/adapter_config.json
# checkpoint-270/adapter_model.safetensors
# checkpoint-270/added_tokens.json
# checkpoint-270/chat_template.jinja
# checkpoint-270/merges.txt
# checkpoint-270/optimizer.pt
# checkpoint-270/rng_state.pth
# checkpoint-270/scaler.pt
# checkpoint-270/scheduler.pt
# checkpoint-270/special_tokens_map.json
# checkpoint-270/tokenizer.json
# checkpoint-270/tokenizer_config.json
# checkpoint-270/trainer_state.json
# checkpoint-270/training_args.bin
# checkpoint-270/vocab.json
# checkpoint-30/
# checkpoint-30/README.md
# checkpoint-30/adapter_config.json
# checkpoint-30/adapter_model.safetensors
# checkpoint-30/added_tokens.json
# checkpoint-30/chat_template.jinja
# checkpoint-30/merges.txt
# checkpoint-30/optimizer.pt
# checkpoint-30/rng_state.pth
# checkpoint-30/scaler.pt
# checkpoint-30/scheduler.pt
# checkpoint-30/special_tokens_map.json
# checkpoint-30/tokenizer.json
# checkpoint-30/tokenizer_config.json
# checkpoint-30/trainer_state.json
# checkpoint-30/training_args.bin
# checkpoint-30/vocab.json
# checkpoint-300/
# checkpoint-300/README.md
# checkpoint-300/adapter_config.json
# checkpoint-300/adapter_model.safetensors
# {"timestamp": "2026-03-27T14:26:36.556320Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/v1/chat/completions", "status_code": 200, "process_time_ms": 7.01}
# {"timestamp": "2026-03-27T14:26:36.787991Z", "level": "error", "event": "Error during GGUF tool streaming: Lost connection to llama-server\nTraceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_transports/default.py\", line 101, in map_httpcore_exceptions\n    yield\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_transports/default.py\", line 250, in handle_request\n    resp = self._pool.handle_request(req)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection_pool.py\", line 256, in handle_request\n    raise exc from None\n  File \"/usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection_pool.py\", line 236, in handle_request\n    response = connection.handle_request(\n               ^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection.py\", line 101, in handle_request\n    raise exc\n  File \"/usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection.py\", line 78, in handle_request\n    stream = self._connect(request)\n             ^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection.py\", line 124, in _connect\n    stream = self._network_backend.connect_tcp(**kwargs)\n             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpcore/_backends/sync.py\", line 207, in connect_tcp\n    with map_exceptions(exc_map):\n         ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/contextlib.py\", line 158, in __exit__\n    self.gen.throw(value)\n  File \"/usr/local/lib/python3.12/dist-packages/httpcore/_exceptions.py\", line 14, in map_exceptions\n    raise to_exc(exc) from exc\nhttpcore.ConnectError: [Errno 111] Connection refused\n\nThe above exception was the direct cause of the following exception:\n\nTraceback (most recent call last):\n  File \"/content/unsloth/studio/backend/core/inference/llama_cpp.py\", line 1710, in generate_chat_completion_with_tools\n    resp = client.post(url, json = payload)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_client.py\", line 1144, in post\n    return self.request(\n           ^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_client.py\", line 825, in request\n    return self.send(request, auth=auth, follow_redirects=follow_redirects)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_client.py\", line 914, in send\n    response = self._send_handling_auth(\n               ^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_client.py\", line 942, in _send_handling_auth\n    response = self._send_handling_redirects(\n               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_client.py\", line 979, in _send_handling_redirects\n    response = self._send_single_request(request)\n               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_client.py\", line 1014, in _send_single_request\n    response = transport.handle_request(request)\n               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_transports/default.py\", line 249, in handle_request\n    with map_httpcore_exceptions():\n         ^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/contextlib.py\", line 158, in __exit__\n    self.gen.throw(value)\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_transports/default.py\", line 118, in map_httpcore_exceptions\n    raise mapped_exc(message) from exc\nhttpx.ConnectError: [Errno 111] Connection refused\n\nDuring handling of the above exception, another exception occurred:\n\nTraceback (most recent call last):\n  File \"/content/unsloth/studio/backend/routes/inference.py\", line 1115, i ...
# checkpoint-300/added_tokens.json
# checkpoint-300/chat_template.jinja
# checkpoint-300/merges.txt
# checkpoint-300/optimizer.pt
# checkpoint-300/rng_state.pth
# checkpoint-300/scaler.pt
# checkpoint-300/scheduler.pt
# checkpoint-300/special_tokens_map.json
# checkpoint-300/tokenizer.json
# checkpoint-300/tokenizer_config.json
# checkpoint-300/trainer_state.json
# checkpoint-300/training_args.bin
# checkpoint-300/vocab.json
# checkpoint-330/
# checkpoint-330/README.md
# checkpoint-330/adapter_config.json
# checkpoint-330/adapter_model.safetensors
# checkpoint-330/added_tokens.json
# checkpoint-330/chat_template.jinja
# checkpoint-330/merges.txt
# checkpoint-330/optimizer.pt
# checkpoint-330/rng_state.pth
# checkpoint-330/scaler.pt
# checkpoint-330/scheduler.pt
# checkpoint-330/special_tokens_map.json
# checkpoint-330/tokenizer.json
# checkpoint-330/tokenizer_config.json
# checkpoint-330/trainer_state.json
# checkpoint-330/training_args.bin
# checkpoint-330/vocab.json
# checkpoint-360/
# checkpoint-360/README.md
# checkpoint-360/adapter_config.json
# checkpoint-360/adapter_model.safetensors
# checkpoint-360/added_tokens.json
# checkpoint-360/chat_template.jinja
# checkpoint-360/merges.txt
# checkpoint-360/optimizer.pt
# checkpoint-360/rng_state.pth
# checkpoint-360/scaler.pt
# checkpoint-360/scheduler.pt
# checkpoint-360/special_tokens_map.json
# checkpoint-360/tokenizer.json
# checkpoint-360/tokenizer_config.json
# checkpoint-360/trainer_state.json
# checkpoint-360/training_args.bin
# checkpoint-360/vocab.json
# checkpoint-390/
# checkpoint-390/README.md
# checkpoint-390/adapter_config.json
# checkpoint-390/adapter_model.safetensors
# checkpoint-390/added_tokens.json
# checkpoint-390/chat_template.jinja
# checkpoint-390/merges.txt
# checkpoint-390/optimizer.pt
# {"timestamp": "2026-03-27T14:27:05.850546Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/v1/chat/completions", "status_code": 200, "process_time_ms": 62.42}
# {"timestamp": "2026-03-27T14:27:06.195096Z", "level": "error", "event": "Error during GGUF tool streaming: Lost connection to llama-server\nTraceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_transports/default.py\", line 101, in map_httpcore_exceptions\n    yield\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_transports/default.py\", line 250, in handle_request\n    resp = self._pool.handle_request(req)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection_pool.py\", line 256, in handle_request\n    raise exc from None\n  File \"/usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection_pool.py\", line 236, in handle_request\n    response = connection.handle_request(\n               ^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection.py\", line 101, in handle_request\n    raise exc\n  File \"/usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection.py\", line 78, in handle_request\n    stream = self._connect(request)\n             ^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection.py\", line 124, in _connect\n    stream = self._network_backend.connect_tcp(**kwargs)\n             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpcore/_backends/sync.py\", line 207, in connect_tcp\n    with map_exceptions(exc_map):\n         ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/contextlib.py\", line 158, in __exit__\n    self.gen.throw(value)\n  File \"/usr/local/lib/python3.12/dist-packages/httpcore/_exceptions.py\", line 14, in map_exceptions\n    raise to_exc(exc) from exc\nhttpcore.ConnectError: [Errno 111] Connection refused\n\nThe above exception was the direct cause of the following exception:\n\nTraceback (most recent call last):\n  File \"/content/unsloth/studio/backend/core/inference/llama_cpp.py\", line 1710, in generate_chat_completion_with_tools\n    resp = client.post(url, json = payload)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_client.py\", line 1144, in post\n    return self.request(\n           ^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_client.py\", line 825, in request\n    return self.send(request, auth=auth, follow_redirects=follow_redirects)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_client.py\", line 914, in send\n    response = self._send_handling_auth(\n               ^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_client.py\", line 942, in _send_handling_auth\n    response = self._send_handling_redirects(\n               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_client.py\", line 979, in _send_handling_redirects\n    response = self._send_single_request(request)\n               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_client.py\", line 1014, in _send_single_request\n    response = transport.handle_request(request)\n               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_transports/default.py\", line 249, in handle_request\n    with map_httpcore_exceptions():\n         ^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/contextlib.py\", line 158, in __exit__\n    self.gen.throw(value)\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_transports/default.py\", line 118, in map_httpcore_exceptions\n    raise mapped_exc(message) from exc\nhttpx.ConnectError: [Errno 111] Connection refused\n\nDuring handling of the above exception, another exception occurred:\n\nTraceback (most recent call last):\n  File \"/content/unsloth/studio/backend/routes/inference.py\", line 1115, i ...
# checkpoint-390/rng_state.pth
# checkpoint-390/scaler.pt
# checkpoint-390/scheduler.pt
# checkpoint-390/special_tokens_map.json
# checkpoint-390/tokenizer.json
# checkpoint-390/tokenizer_config.json
# checkpoint-390/trainer_state.json
# checkpoint-390/training_args.bin
# checkpoint-390/vocab.json
# checkpoint-396/
# checkpoint-396/README.md
# checkpoint-396/adapter_config.json
# checkpoint-396/adapter_model.safetensors
# checkpoint-396/added_tokens.json
# checkpoint-396/chat_template.jinja
# checkpoint-396/merges.txt
# checkpoint-396/optimizer.pt
# checkpoint-396/rng_state.pth
# checkpoint-396/scaler.pt
# checkpoint-396/scheduler.pt
# checkpoint-396/special_tokens_map.json
# checkpoint-396/tokenizer.json
# checkpoint-396/tokenizer_config.json
# checkpoint-396/trainer_state.json
# checkpoint-396/training_args.bin
# checkpoint-396/vocab.json
# checkpoint-60/
# checkpoint-60/README.md
# checkpoint-60/adapter_config.json
# checkpoint-60/adapter_model.safetensors
# {"timestamp": "2026-03-27T14:27:13.862829Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/v1/chat/completions", "status_code": 200, "process_time_ms": 7.1}
# {"timestamp": "2026-03-27T14:27:14.012527Z", "level": "error", "event": "Error during GGUF tool streaming: Lost connection to llama-server\nTraceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_transports/default.py\", line 101, in map_httpcore_exceptions\n    yield\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_transports/default.py\", line 250, in handle_request\n    resp = self._pool.handle_request(req)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection_pool.py\", line 256, in handle_request\n    raise exc from None\n  File \"/usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection_pool.py\", line 236, in handle_request\n    response = connection.handle_request(\n               ^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection.py\", line 101, in handle_request\n    raise exc\n  File \"/usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection.py\", line 78, in handle_request\n    stream = self._connect(request)\n             ^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection.py\", line 124, in _connect\n    stream = self._network_backend.connect_tcp(**kwargs)\n             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpcore/_backends/sync.py\", line 207, in connect_tcp\n    with map_exceptions(exc_map):\n         ^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/contextlib.py\", line 158, in __exit__\n    self.gen.throw(value)\n  File \"/usr/local/lib/python3.12/dist-packages/httpcore/_exceptions.py\", line 14, in map_exceptions\n    raise to_exc(exc) from exc\nhttpcore.ConnectError: [Errno 111] Connection refused\n\nThe above exception was the direct cause of the following exception:\n\nTraceback (most recent call last):\n  File \"/content/unsloth/studio/backend/core/inference/llama_cpp.py\", line 1710, in generate_chat_completion_with_tools\n    resp = client.post(url, json = payload)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_client.py\", line 1144, in post\n    return self.request(\n           ^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_client.py\", line 825, in request\n    return self.send(request, auth=auth, follow_redirects=follow_redirects)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_client.py\", line 914, in send\n    response = self._send_handling_auth(\n               ^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_client.py\", line 942, in _send_handling_auth\n    response = self._send_handling_redirects(\n               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_client.py\", line 979, in _send_handling_redirects\n    response = self._send_single_request(request)\n               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_client.py\", line 1014, in _send_single_request\n    response = transport.handle_request(request)\n               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_transports/default.py\", line 249, in handle_request\n    with map_httpcore_exceptions():\n         ^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/contextlib.py\", line 158, in __exit__\n    self.gen.throw(value)\n  File \"/usr/local/lib/python3.12/dist-packages/httpx/_transports/default.py\", line 118, in map_httpcore_exceptions\n    raise mapped_exc(message) from exc\nhttpx.ConnectError: [Errno 111] Connection refused\n\nDuring handling of the above exception, another exception occurred:\n\nTraceback (most recent call last):\n  File \"/content/unsloth/studio/backend/routes/inference.py\", line 1115, i ...
# checkpoint-60/added_tokens.json
# checkpoint-60/chat_template.jinja
# checkpoint-60/merges.txt
# checkpoint-60/optimizer.pt
# checkpoint-60/rng_state.pth
# checkpoint-60/scaler.pt
# checkpoint-60/scheduler.pt
# checkpoint-60/special_tokens_map.json
# checkpoint-60/tokenizer.json
# checkpoint-60/tokenizer_config.json
# checkpoint-60/trainer_state.json
# checkpoint-60/training_args.bin
# checkpoint-60/vocab.json
# checkpoint-90/
# checkpoint-90/README.md
# checkpoint-90/adapter_config.json
# checkpoint-90/adapter_model.safetensors
# checkpoint-90/added_tokens.json
# checkpoint-90/chat_template.jinja
# checkpoint-90/merges.txt
# checkpoint-90/optimizer.pt
# checkpoint-90/rng_state.pth
# checkpoint-90/scaler.pt
# checkpoint-90/scheduler.pt
# checkpoint-90/special_tokens_map.json
# checkpoint-90/tokenizer.json
# checkpoint-90/tokenizer_config.json
# checkpoint-90/trainer_state.json
# checkpoint-90/training_args.bin
# checkpoint-90/vocab.json
#
# sent 6.09G bytes  received 4.60K bytes  60.03M bytes/sec
# total size is 6.09G  speedup is 1.00

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other resources:
# 1. Looking to use Unsloth locally? Read our [Installation Guide](https://unsloth.ai/docs/get-started/install) for details on installing Unsloth on Windows, Docker, AMD, Intel GPUs.
# 2. Learn how to do Reinforcement Learning with our [RL Guide and notebooks](https://unsloth.ai/docs/get-started/reinforcement-learning-rl-guide).
# 3. Read our guides and notebooks for [Text-to-speech (TTS)](https://unsloth.ai/docs/basics/text-to-speech-tts-fine-tuning) and [vision](https://unsloth.ai/docs/basics/vision-fine-tuning) model support.
# 4. Explore our [LLM Tutorials Directory](https://unsloth.ai/docs/models/tutorials-how-to-fine-tune-and-run-llms) to find dedicated guides for each model.
# 5. Need help with Inference? Read our [Inference & Deployment page](https://unsloth.ai/docs/basics/inference-and-deployment) for details on using vLLM, llama.cpp, Ollama etc.
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
#
#   <b>This notebook is licensed <a href="https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0">AGPL-3.0</a></b>
# </div>
