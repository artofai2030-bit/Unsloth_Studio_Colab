# %% [markdown]
# <a href="https://colab.research.google.com/github/artofai2030-bit/Unsloth_Studio_Colab/blob/main/studio/Unsloth_Studio_Colab-new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth Studio on your local device, follow [our guide](https://unsloth.ai/docs/new/unsloth-studio/install). Unsloth Studio is licensed [AGPL-3.0](https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0).
#
# ### Unsloth Studio
#
# Train and run open models with [**Unsloth Studio**](https://unsloth.ai/docs/new/unsloth-studio/start). NEW! Installation should now only take 2 mins!
#
#
# We are actively working on making Unsloth Studio install on Colab T4 GPUs faster.
#
# [Features](https://unsloth.ai/docs/new/unsloth-studio#features) • [Quickstart](https://unsloth.ai/docs/new/unsloth-studio/start) • [Data Recipes](https://unsloth.ai/docs/new/unsloth-studio/data-recipe) • [Studio Chat](https://unsloth.ai/docs/new/unsloth-studio/chat) • [Export](https://unsloth.ai/docs/new/unsloth-studio/export)

# %% [markdown]
# <p align="left"><img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/studio%20github%20landscape%20colab%20display.png" width="600"></p>

# %% [markdown]
# ### Setup: Clone repo and run setup

# %%
# !git clone --depth 1 --branch main https://github.com/unslothai/unsloth.git
# %cd /content/unsloth
# !chmod +x studio/setup.sh && ./studio/setup.sh
# Out:
# Cloning into 'unsloth'...
# remote: Enumerating objects: 1037, done.
# remote: Counting objects: 100% (1037/1037), done.
# remote: Compressing objects: 100% (863/863), done.
# remote: Total 1037 (delta 178), reused 687 (delta 154), pack-reused 0 (from 0)
# Receiving objects: 100% (1037/1037), 31.11 MiB | 21.51 MiB/s, done.
# Resolving deltas: 100% (178/178), done.
# /content/unsloth
# ╔══════════════════════════════════════╗
# ║     Unsloth Studio Update Script     ║
# ╚══════════════════════════════════════╝
# ✅ Node v20.19.0 and npm 10.8.2 detected in Colab.
#    Upgrading npm to latest...
# ✅ Node v20.19.0 | npm 11.12.1
#    Installing bun (faster frontend package installs)...
#    bun installed (1.3.11)
#    Using bun for package install (faster)
# ✅ Frontend built to frontend/dist
#    Colab detected, installing Studio backend dependencies...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.5/69.5 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 340.4/340.4 kB 20.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 104.7 MB/s eta 0:00:00
# ✅ Studio backend dependencies installed into system Python
# [====================] 11/11  finalizing
# ✅ Python dependencies installed
#
#    Pre-installing transformers 5.x for newer model support...
# ✅ Transformers 5.x pre-installed to /root/.unsloth/studio/.venv_t5/
#
# Resolved llama.cpp release tag: b8508
#
# Installing prebuilt llama.cpp bundle (preferred path)...
# [llama-prebuilt] no existing llama.cpp install detected at /root/.unsloth/llama.cpp; performing fresh prebuilt install
# [llama-prebuilt] published_release: repo=unslothai/llama.cpp
# [llama-prebuilt] published_release: tag=b8508
# [llama-prebuilt] published_release: manifest=llama-prebuilt-manifest.json
# [llama-prebuilt] published_release: upstream_tag=b8508
# [llama-prebuilt] torch_cuda_preference: selected runtime_line=cuda12 from torch.version.cuda=12.8
# [llama-prebuilt] linux_cuda_selection: release=b8508
# [llama-prebuilt] linux_cuda_selection: detected_sms=75
# [llama-prebuilt] linux_cuda_selection: detected_runtime_lines=cuda12
# [llama-prebuilt] linux_cuda_selection: driver_runtime_lines=cuda13,cuda12
# [llama-prebuilt] linux_cuda_selection: compatible_runtime_lines=cuda12
# [llama-prebuilt] linux_cuda_selection: runtime_dirs cuda13=none
# [llama-prebuilt] linux_cuda_selection: runtime_dirs cuda12=/usr/local/cuda-12.8/targets/x86_64-linux/lib,/usr/local/lib/python3.12/dist-packages/nvidia/cuda_runtime/lib,/usr/local/lib/python3.12/dist-packages/nvidia/cublas/lib
# [llama-prebuilt] linux_cuda_selection: published_assets=app-b8508-linux-x64-cuda12-newer.tar.gz,app-b8508-linux-x64-cuda12-older.tar.gz,app-b8508-linux-x64-cuda12-portable.tar.gz,app-b8508-linux-x64-cuda13-newer.tar.gz,app-b8508-linux-x64-cuda13-older.tar.gz,app-b8508-linux-x64-cuda13-portable.tar.gz
# [llama-prebuilt] linux_cuda_selection: torch_preferred_runtime_line=cuda12 reordered_attempts=cuda12
# [llama-prebuilt] linux_cuda_selection: accept app-b8508-linux-x64-cuda12-older.tar.gz runtime_line=cuda12 coverage_class=older coverage=70-89 supported=70,75,80,86,89
# [llama-prebuilt] linux_cuda_selection: reject app-b8508-linux-x64-cuda12-newer.tar.gz runtime_line=cuda12 coverage_class=newer coverage=86-120 supported=86,89,90,100,120 reasons=missing_sms=75 out_of_range_sms=75
# [llama-prebuilt] linux_cuda_selection: accept app-b8508-linux-x64-cuda12-portable.tar.gz runtime_line=cuda12 coverage_class=portable coverage=70-120 supported=70,75,80,86,89,90,100,120
# [llama-prebuilt] linux_cuda_selection: attempt_order=app-b8508-linux-x64-cuda12-older.tar.gz,app-b8508-linux-x64-cuda12-portable.tar.gz
# [llama-prebuilt] selected app-b8508-linux-x64-cuda12-older.tar.gz (published) for Linux x86_64
# [llama-prebuilt] downloading tiny GGUF validation model
# [llama-prebuilt] created install staging dir /root/.unsloth/.staging/llama.cpp.staging-kv8pj1df
# [llama-prebuilt] hydrating upstream llama.cpp source for b8508 into /root/.unsloth/.staging/llama.cpp.staging-kv8pj1df
# [llama-prebuilt] downloading llama.cpp source tree for upstream tag b8508
# [llama-prebuilt] verified llama.cpp source tree for b8508 sha256=a41d2c532c44ff6fc79da2a3d306d6e4f654e32e88fe886e496a55c338774f9f
# [llama-prebuilt] overlaying prebuilt bundle app-b8508-linux-x64-cuda12-older.tar.gz into /root/.unsloth/.staging/llama.cpp.staging-kv8pj1df
# [llama-prebuilt] downloading app-b8508-linux-x64-cuda12-older.tar.gz from published release
# [llama-prebuilt] verified prebuilt archive app-b8508-linux-x64-cuda12-older.tar.gz sha256=d40fb39a6f215459fa6cddcabf6b8661617caac500cff9961fdc91120176f7cc
# [llama-prebuilt] staged prebuilt validation succeeded for app-b8508-linux-x64-cuda12-older.tar.gz
# [llama-prebuilt] activating staged install /root/.unsloth/.staging/llama.cpp.staging-kv8pj1df -> /root/.unsloth/llama.cpp
# [llama-prebuilt] activated staged install at /root/.unsloth/llama.cpp
# [llama-prebuilt] confirming activated install tree at /root/.unsloth/llama.cpp
# [llama-prebuilt] activated install tree confirmed at /root/.unsloth/llama.cpp
# ✅ Prebuilt llama.cpp installed and validated
#
# ╔══════════════════════════════════════╗
# ║          Update Complete!            ║
# ╠══════════════════════════════════════╣
# ║ Unsloth Studio is ready to start     ║
# ║ in your Colab notebook!              ║
# ║                                      ║
# ║ from colab import start              ║
# ║ start()                              ║
# ╚══════════════════════════════════════╝

# %% [markdown]
# ### Start Unsloth Studio

# %%
import sys, time
sys.path.insert(0, "/content/unsloth/studio/backend")
from colab import start
start()
# Out:
# {"timestamp": "2026-03-27T09:39:12.261000Z", "level": "info", "event": "\ud83e\udda5 Starting Unsloth Studio..."}
# {"timestamp": "2026-03-27T09:39:12.262262Z", "level": "info", "event": "   Loading backend..."}
# {"timestamp": "2026-03-27T09:39:12.262780Z", "level": "info", "event": "   Starting server..."}
# INFO:     Started server process [915]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8889 (Press CTRL+C to quit)
# Hardware detected: CUDA — Tesla T4
# {"timestamp": "2026-03-27T09:39:12.387700Z", "level": "info", "event": "Pre-caching helper GGUF: unsloth/Qwen3.5-4B-GGUF/Qwen3.5-4B-UD-Q4_K_XL.gguf"}
# {"timestamp": "2026-03-27T09:39:12.468226Z", "level": "info", "event": "Helper GGUF cached: 1 file(s)"}
# {"timestamp": "2026-03-27T09:39:15.275965Z", "level": "info", "event": "   Server started!"}
#     <div style="display: inline-block; padding: 20px; background: #ffffff; border: 2px solid #000000;
#                 border-radius: 12px; margin: 10px 0; font-family: system-ui, -apple-system, sans-serif;">
#         <h2 style="color: #000000; margin: 0 0 12px 0; font-size: 26px; font-weight: 800;
#                    display: flex; align-items: center; gap: 12px;">
#             <img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/unsloth-gem.png"
#                  height="48" style="display:block;">
#             Unsloth Studio is Ready!
#         </h2>
#         <a href="https://8888-gpu-t4-s-kkb-usw4a2-2zx7ie6zgfva7-a.us-west4-2.prod.colab.dev" target="_blank"
#            style="display: inline-flex; align-items: center; gap: 10px; padding: 14px 28px;
#                   background: #000000; color: white; text-decoration: none; border-radius: 8px;
#                   font-weight: 800; font-size: 16px;">
#             <svg xmlns="http://www.w3.org/2000/svg" width="18" height="18" viewBox="0 0 24 24" fill="white"><polygon points="5,3 19,12 5,21"/></svg>
#             Open Unsloth Studio
#         </a>
#         <p style="color: #333333; margin: 16px 0 0 0; font-size: 13px; font-family: monospace;">
#             https://8888-gpu-...
#         </p>
#     </div>

# %%
from google.colab import output
output.serve_kernel_port_as_iframe(8888, height = 1200, width = "100%")
for _ in range(10000): time.sleep(300), print("=", end = "")
# Out:
# {"timestamp": "2026-03-27T09:39:16.263592Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 1.24}
# {"timestamp": "2026-03-27T09:39:20.138822Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 1.7}
# {"timestamp": "2026-03-27T09:39:30.738682Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 0.88}
# {"timestamp": "2026-03-27T09:39:31.062365Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 0.58}
# {"timestamp": "2026-03-27T09:39:31.102266Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.58}
# {"timestamp": "2026-03-27T09:39:31.388071Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.18}
# {"timestamp": "2026-03-27T09:39:31.494002Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.83}
# {"timestamp": "2026-03-27T09:39:31.802391Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.58}
# {"timestamp": "2026-03-27T09:39:32.174410Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.6}
# {"timestamp": "2026-03-27T09:39:32.537248Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.43}
# {"timestamp": "2026-03-27T09:39:40.357590Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/login", "status_code": 200, "process_time_ms": 75.18}
# {"timestamp": "2026-03-27T09:39:41.328460Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/change-password", "status_code": 200, "process_time_ms": 152.42}
# {"timestamp": "2026-03-27T09:39:41.822535Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.31}
# {"timestamp": "2026-03-27T09:39:42.083824Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.52}
# {"timestamp": "2026-03-27T09:39:42.385527Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.37}
# {"timestamp": "2026-03-27T09:39:47.806463Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.38}
# {"timestamp": "2026-03-27T09:40:06.824952Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/studio", "status_code": 200, "process_time_ms": 2.14}
# {"timestamp": "2026-03-27T09:40:23.397771Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 0.49}
# {"timestamp": "2026-03-27T09:40:23.741796Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.41}
# {"timestamp": "2026-03-27T09:40:59.196247Z", "level": "info", "event": "TrainingBackend initialized (subprocess mode)"}
# {"timestamp": "2026-03-27T09:40:59.748915Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 3.21}
# {"timestamp": "2026-03-27T09:42:02.871627Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/upload", "status_code": 200, "process_time_ms": 38169.59}
# {"timestamp": "2026-03-27T09:42:03.262204Z", "level": "info", "event": "Checking format for dataset: /root/.unsloth/studio/assets/datasets/uploads/348b0806ddcb4a96bb657d73130969ae_chat_unsloth_chatml_with_topic.colab_prompt_completion.jsonl"}
# {"timestamp": "2026-03-27T09:42:03.294470Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 5.37}
# Generating train split: 0 examples [00:00, ? examples/s]
# {"timestamp": "2026-03-27T09:42:03.974492Z", "level": "info", "event": "Format check result: requires_mapping=False, format=custom_heuristic, is_image=False"}
# {"timestamp": "2026-03-27T09:42:03.977632Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 719.72}
# {"timestamp": "2026-03-27T09:42:38.495510Z", "level": "info", "event": "Getting model config for: qwen/qwen3-4b-instruct-2507"}
# {"timestamp": "2026-03-27T09:42:38.503061Z", "level": "info", "event": "Loaded model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/qwen/unsloth_Qwen3-4B-Instruct-2507.yaml (via mapping)"}
# config.json:   0%|          | 0.00/727 [00:00<?, ?B/s]
# {"timestamp": "2026-03-27T09:42:40.342911Z", "level": "info", "event": "Model config result for qwen/qwen3-4b-instruct-2507: is_vision=False, is_embedding=False, audio_type=None, is_lora=False, max_position_embeddings=262144"}
# {"timestamp": "2026-03-27T09:42:40.518149Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/config/Qwen/Qwen3-4B-Instruct-2507", "status_code": 200, "process_time_ms": 2025.63}
# {"timestamp": "2026-03-27T09:42:50.872539Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 1.99}
# {"timestamp": "2026-03-27T09:42:55.846408Z", "level": "info", "event": "Checking format for dataset: /root/.unsloth/studio/assets/datasets/uploads/348b0806ddcb4a96bb657d73130969ae_chat_unsloth_chatml_with_topic.colab_prompt_completion.jsonl"}
# {"timestamp": "2026-03-27T09:42:56.064289Z", "level": "info", "event": "Format check result: requires_mapping=False, format=custom_heuristic, is_image=False"}
# {"timestamp": "2026-03-27T09:42:56.066457Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 222.27}
# {"timestamp": "2026-03-27T09:43:42.752547Z", "level": "info", "event": "Checking format for dataset: /root/.unsloth/studio/assets/datasets/uploads/348b0806ddcb4a96bb657d73130969ae_chat_unsloth_chatml_with_topic.colab_prompt_completion.jsonl"}
# {"timestamp": "2026-03-27T09:43:42.990959Z", "level": "info", "event": "Format check result: requires_mapping=False, format=custom_heuristic, is_image=False"}
# {"timestamp": "2026-03-27T09:43:42.994253Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 243.75}
# {"timestamp": "2026-03-27T09:43:44.571387Z", "level": "info", "event": "Starting training job with model: Qwen/Qwen3-4B-Instruct-2507"}
# {"timestamp": "2026-03-27T09:43:44.572450Z", "level": "info", "event": "Found local dataset file: /root/.unsloth/studio/assets/datasets/uploads/348b0806ddcb4a96bb657d73130969ae_chat_unsloth_chatml_with_topic.colab_prompt_completion.jsonl"}
# {"timestamp": "2026-03-27T09:43:44.578846Z", "level": "info", "event": "Loaded model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/qwen/unsloth_Qwen3-4B-Instruct-2507.yaml (via mapping)"}
# {"timestamp": "2026-03-27T09:43:44.580511Z", "level": "info", "event": "InferenceOrchestrator initialized (subprocess mode)"}
# {"timestamp": "2026-03-27T09:43:44.582006Z", "level": "info", "event": "ExportOrchestrator initialized (subprocess mode)"}
# {"timestamp": "2026-03-27T09:43:44.608186Z", "level": "info", "event": "Training subprocess started (pid=3675)"}
# {"timestamp": "2026-03-27T09:43:44.637579Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/train/start", "status_code": 200, "process_time_ms": 68.78}
# {"timestamp": "2026-03-27T09:43:45.149509Z", "level": "info", "event": "Top GGUF models: ['unsloth/Qwen3.5-35B-A3B-GGUF', 'unsloth/Qwen3.5-9B-GGUF', 'unsloth/Qwen3.5-27B-GGUF', 'unsloth/Qwen3.5-4B-GGUF', 'unsloth/Qwen3.5-122B-A10B-GGUF', 'unsloth/gpt-oss-20b-GGUF', 'unsloth/Qwen3-Coder-Next-GGUF', 'unsloth/Qwen3.5-0.8B-GGUF', 'unsloth/GLM-4.7-Flash-GGUF', 'unsloth/Qwen3.5-2B-GGUF', 'unsloth/LTX-2.3-GGUF', 'unsloth/Nemotron-3-Nano-30B-A3B-GGUF', 'unsloth/Qwen3.5-397B-A17B-GGUF', 'unsloth/Qwen3.5-35B-A3B-Experiments-GGUF', 'unsloth/Qwen3-VL-4B-Instruct-GGUF', 'unsloth/Qwen3-Coder-30B-A3B-Instruct-GGUF', 'unsloth/gemma-3-27b-it-GGUF', 'unsloth/gpt-oss-120b-GGUF', 'unsloth/Qwen-Image-Edit-2511-GGUF', 'unsloth/Llama-3.2-1B-Instruct-GGUF', 'unsloth/GLM-4.6V-Flash-GGUF', 'unsloth/gemma-3-12b-it-GGUF', 'unsloth/DeepSeek-R1-Distill-Qwen-1.5B-GGUF', 'unsloth/Qwen3-4B-Instruct-2507-GGUF', 'unsloth/gemma-3-270m-it-GGUF', 'unsloth/Qwen3-4B-GGUF', 'unsloth/NVIDIA-Nemotron-3-Super-120B-A12B-GGUF', 'unsloth/DeepSeek-R1-0528-Qwen3-8B-GGUF', 'unsloth/Qwen3-VL-30B-A3B-Instruct-GGUF', 'unsloth/Qwen2.5-VL-7B-Instruct-GGUF', 'unsloth/gemma-3-4b-it-GGUF', 'unsloth/MiniMax-M2.5-GGUF', 'unsloth/Qwen3-0.6B-GGUF', 'unsloth/DeepSeek-R1-Distill-Qwen-14B-GGUF', 'unsloth/Qwen3-VL-8B-Instruct-GGUF']"}
# {"timestamp": "2026-03-27T09:43:45.150970Z", "level": "info", "event": "Top hub models: ['unsloth/GLM-4.7-Flash-FP8-Dynamic', 'unsloth/mistral-7b-v0.3-bnb-4bit', 'unsloth/Meta-Llama-3.1-8B-Instruct', 'unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit', 'unsloth/DeepSeek-OCR-2', 'unsloth/Qwen3-0.6B', 'unsloth/gpt-oss-20b', 'unsloth/Llama-3.2-1B-Instruct', 'unsloth/Qwen3-0.6B-unsloth-bnb-4bit', 'unsloth/Qwen3-14B-unsloth-bnb-4bit', 'unsloth/Llama-3.1-8B-Instruct', 'unsloth/gpt-oss-20b-unsloth-bnb-4bit', 'unsloth/Llama-3.2-3B-Instruct', 'unsloth/Qwen2.5-7B-Instruct-bnb-4bit', 'unsloth/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit', 'unsloth/Qwen3.5-9B', 'unsloth/Qwen3.5-4B', 'unsloth/GLM-4.7-Flash', 'unsloth/Qwen2.5-3B-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen2.5-7B', 'unsloth/Qwen3-1.7B-unsloth-bnb-4bit', 'unsloth/Qwen2-7B', 'unsloth/gpt-oss-120b-BF16', 'unsloth/Qwen3.5-2B', 'unsloth/Qwen3-4B-Base', 'unsloth/gpt-oss-20b-BF16', 'unsloth/Qwen3-8B-unsloth-bnb-4bit', 'unsloth/Llama-3.2-1B-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen3-4B', 'unsloth/Qwen3-8B', 'unsloth/Qwen2.5-7B-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen3-4B-bnb-4bit', 'unsloth/Qwen3.5-0.8B', 'unsloth/Qwen2.5-7B-Instruct', 'unsloth/Llama-3.2-3B-Instruct-unsloth-bnb-4bit', 'unsloth/llama-3-8b-bnb-4bit', 'unsloth/Qwen3-4B-unsloth-bnb-4bit', 'unsloth/DeepSeek-V3-0324-BF16', 'unsloth/Qwen3-VL-4B-Instruct-unsloth-bnb-4bit', 'unsloth/embeddinggemma-300m']"}
# {"timestamp": "2026-03-27T09:43:54.896269Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/progress", "status_code": 200, "process_time_ms": 4.71}
# ==={"timestamp": "2026-03-27T09:54:47.990568Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 4.29}
# {"timestamp": "2026-03-27T09:54:47.993256Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 6.88}
# {"timestamp": "2026-03-27T09:54:48.055043Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.53}
# {"timestamp": "2026-03-27T09:54:49.217659Z", "level": "info", "event": "Found 1 training runs in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-03-27T09:54:49.218785Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/checkpoints", "status_code": 200, "process_time_ms": 3.4}
# {"timestamp": "2026-03-27T09:55:29.709378Z", "level": "info", "event": "Spawning fresh export subprocess for '/root/.unsloth/studio/outputs/Qwen_Qwen3-4B-Instruct-2507_1774604815'"}
# {"timestamp": "2026-03-27T09:55:29.716640Z", "level": "info", "event": "Export subprocess started (pid=6825)"}
# {"timestamp": "2026-03-27T09:55:30.403662Z", "level": "info", "event": "Export subprocess status: Importing Unsloth..."}
# {"timestamp": "2026-03-27T09:56:02.128267Z", "level": "info", "event": "Export subprocess status: Loading checkpoint: /root/.unsloth/studio/outputs/Qwen_Qwen3-4B-Instruct-2507_1774604815"}
# {"timestamp": "2026-03-27T09:57:31.503462Z", "level": "info", "event": "Checkpoint '/root/.unsloth/studio/outputs/Qwen_Qwen3-4B-Instruct-2507_1774604815' loaded in subprocess"}
# {"timestamp": "2026-03-27T09:57:31.505071Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/export/load-checkpoint", "status_code": 200, "process_time_ms": 121799.49}
# ===={"timestamp": "2026-03-27T10:14:54.347300Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/export/export/gguf", "status_code": 200, "process_time_ms": 1042233.01}
# ==={"timestamp": "2026-03-27T10:31:16.844294Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/export/export/gguf", "status_code": 200, "process_time_ms": 982489.75}
# {"timestamp": "2026-03-27T10:31:26.759166Z", "level": "info", "event": "Export subprocess shut down"}
# {"timestamp": "2026-03-27T10:31:26.760653Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/export/cleanup", "status_code": 200, "process_time_ms": 9909.08}
# ={"timestamp": "2026-03-27T10:35:48.315663Z", "level": "info", "event": "Spawning fresh export subprocess for '/root/.unsloth/studio/outputs/Qwen_Qwen3-4B-Instruct-2507_1774604815'"}
# {"timestamp": "2026-03-27T10:35:48.324267Z", "level": "info", "event": "Export subprocess started (pid=20402)"}
# {"timestamp": "2026-03-27T10:35:49.361918Z", "level": "info", "event": "Export subprocess status: Importing Unsloth..."}
# {"timestamp": "2026-03-27T10:36:27.876031Z", "level": "info", "event": "Export subprocess status: Loading checkpoint: /root/.unsloth/studio/outputs/Qwen_Qwen3-4B-Instruct-2507_1774604815"}
# {"timestamp": "2026-03-27T10:36:53.895196Z", "level": "info", "event": "Checkpoint '/root/.unsloth/studio/outputs/Qwen_Qwen3-4B-Instruct-2507_1774604815' loaded in subprocess"}
# {"timestamp": "2026-03-27T10:36:53.896633Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/export/load-checkpoint", "status_code": 200, "process_time_ms": 65583.35}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_915/3552804093.py in <cell line: 0>()
#       1 from google.colab import output
#       2 output.serve_kernel_port_as_iframe(8888, height = 1200, width = "100%")
# ----> 3 for _ in range(10000): time.sleep(300), print("=", end = "")
#
# KeyboardInterrupt:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# {"timestamp": "2026-03-27T10:37:34.377658Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/export/export/gguf", "status_code": 400, "process_time_ms": 39967.17}
# {"timestamp": "2026-03-27T10:37:34.659776Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/export/cleanup", "status_code": 200, "process_time_ms": 1.72}
# Mounted at /content/drive

# %%
# !mkdir -p /content/drive/MyDrive/unsloth_exports
# !rsync -avh /root/.unsloth/studio/exports/ /content/drive/MyDrive/unsloth_exports/
# Out:
# sending incremental file list
# ./
# Qwen3-4B-Instruct-2507-finetune-gguf/
# Qwen3-4B-Instruct-2507-finetune-gguf/export_metadata.json
# Qwen3-4B-Instruct-2507-finetune-gguf/qwen3-4b-instruct-2507.Q4_K_M.gguf
# {"timestamp": "2026-03-27T10:39:09.269105Z", "level": "info", "event": "Found 1 training runs in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-03-27T10:39:09.274016Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 12.9}
# {"timestamp": "2026-03-27T10:39:09.276374Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/checkpoints", "status_code": 200, "process_time_ms": 15.1}
# {"timestamp": "2026-03-27T10:39:10.321933Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 6.27}
# {"timestamp": "2026-03-27T10:39:10.329379Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 4.89}
# {"timestamp": "2026-03-27T10:39:10.649655Z", "level": "info", "event": "Found 1 trained LoRA adapters in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-03-27T10:39:10.650517Z", "level": "info", "event": "Detected base model from adapter_config.json: unsloth/Qwen3-4B-Instruct-2507"}
# {"timestamp": "2026-03-27T10:39:10.653898Z", "level": "info", "event": "Found 1 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-03-27T10:39:10.654764Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 6.83}
# {"timestamp": "2026-03-27T10:39:13.090732Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/cached-gguf", "status_code": 200, "process_time_ms": 35.81}
# {"timestamp": "2026-03-27T10:39:13.587774Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/cached-models", "status_code": 200, "process_time_ms": 8.41}
# Qwen3-4B-Instruct-2507-finetune-gguf/model/
# Qwen3-4B-Instruct-2507-finetune-gguf/model/added_tokens.json
# Qwen3-4B-Instruct-2507-finetune-gguf/model/chat_template.jinja
# Qwen3-4B-Instruct-2507-finetune-gguf/model/config.json
# Qwen3-4B-Instruct-2507-finetune-gguf/model/merges.txt
# Qwen3-4B-Instruct-2507-finetune-gguf/model/model.safetensors.index.json
# Qwen3-4B-Instruct-2507-finetune-gguf/model/special_tokens_map.json
# Qwen3-4B-Instruct-2507-finetune-gguf/model/tokenizer.json
# Qwen3-4B-Instruct-2507-finetune-gguf/model/tokenizer_config.json
# Qwen3-4B-Instruct-2507-finetune-gguf/model/vocab.json
# Qwen3-4B-Instruct-2507-finetune-gguf/model/.cache/
# Qwen3-4B-Instruct-2507-finetune-gguf/model/.cache/huggingface/
# Qwen3-4B-Instruct-2507-finetune-gguf/model/.cache/huggingface/.gitignore
# Qwen3-4B-Instruct-2507-finetune-gguf/model/.cache/huggingface/download/
# Qwen3-4B-Instruct-2507-finetune-gguf/model/.cache/huggingface/download/aoe4E07IMh7reFyUkVoVk040mQk=.949954f3302e7ab4caf2de4013c9ebad1fdc2f38fe2e72c129e71d0cc246abc1.incomplete
# {"timestamp": "2026-03-27T10:39:16.095437Z", "level": "info", "event": "Detected local GGUF model: /root/.unsloth/studio/exports/Qwen3-4B-Instruct-2507-finetune-gguf/qwen3-4b-instruct-2507.Q4_K_M.gguf"}
# {"timestamp": "2026-03-27T10:39:16.431954Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/inference/validate", "status_code": 200, "process_time_ms": 338.54}
# {"timestamp": "2026-03-27T10:39:16.606177Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.78}
# {"timestamp": "2026-03-27T10:39:19.599965Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.7}
# {"timestamp": "2026-03-27T10:39:20.127775Z", "level": "info", "event": "Detected local GGUF model: /root/.unsloth/studio/exports/Qwen3-4B-Instruct-2507-finetune-gguf/qwen3-4b-instruct-2507.Q4_K_M.gguf"}
# {"timestamp": "2026-03-27T10:39:20.267714Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 3.95}
# {"timestamp": "2026-03-27T10:39:20.843755Z", "level": "info", "event": "GGUF metadata: context_length=262144"}
# {"timestamp": "2026-03-27T10:39:20.861913Z", "level": "info", "event": "GGUF metadata: chat_template=4040 chars"}
# {"timestamp": "2026-03-27T10:39:20.863969Z", "level": "info", "event": "GGUF metadata: model supports tool calling"}
# {"timestamp": "2026-03-27T10:39:20.931396Z", "level": "info", "event": "GGUF size: 2.3 GB, GPUs free: [(0, 14910)], selected: [0], fit: False"}
# {"timestamp": "2026-03-27T10:39:20.934208Z", "level": "info", "event": "Starting llama-server: /root/.unsloth/llama.cpp/llama-server -m /root/.unsloth/studio/exports/Qwen3-4B-Instruct-2507-finetune-gguf/qwen3-4b-instruct-2507.Q4_K_M.gguf --port 35775 -c 4096 --parallel 1 --flash-attn on -ngl -1 --jinja"}
# {"timestamp": "2026-03-27T10:39:22.118987Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 1.59}
# Qwen3-4B-Instruct-2507-finetune-gguf/model/.cache/huggingface/download/model.safetensors.index.json.metadata
#
# sent 3.15G bytes  received 317 bytes  84.11M bytes/sec
# total size is 3.15G  speedup is 1.00

# %%
# !mkdir -p /content/drive/MyDrive/unsloth_outputs
# !rsync -avh /root/.unsloth/studio/outputs/ /content/drive/MyDrive/unsloth_outputs/
# Out:
# sending incremental file list
# ./
# Qwen_Qwen3-4B-Instruct-2507_1774604815/
# Qwen_Qwen3-4B-Instruct-2507_1774604815/README.md
# Qwen_Qwen3-4B-Instruct-2507_1774604815/adapter_config.json
# Qwen_Qwen3-4B-Instruct-2507_1774604815/adapter_model.safetensors
# Qwen_Qwen3-4B-Instruct-2507_1774604815/added_tokens.json
# Qwen_Qwen3-4B-Instruct-2507_1774604815/chat_template.jinja
# Qwen_Qwen3-4B-Instruct-2507_1774604815/merges.txt
# Qwen_Qwen3-4B-Instruct-2507_1774604815/special_tokens_map.json
# Qwen_Qwen3-4B-Instruct-2507_1774604815/tokenizer.json
# Qwen_Qwen3-4B-Instruct-2507_1774604815/tokenizer_config.json
# Qwen_Qwen3-4B-Instruct-2507_1774604815/training_args.bin
# Qwen_Qwen3-4B-Instruct-2507_1774604815/vocab.json
# Qwen_Qwen3-4B-Instruct-2507_1774604815/checkpoint-30/
# Qwen_Qwen3-4B-Instruct-2507_1774604815/checkpoint-30/README.md
# Qwen_Qwen3-4B-Instruct-2507_1774604815/checkpoint-30/adapter_config.json
# Qwen_Qwen3-4B-Instruct-2507_1774604815/checkpoint-30/adapter_model.safetensors
# Qwen_Qwen3-4B-Instruct-2507_1774604815/checkpoint-30/added_tokens.json
# Qwen_Qwen3-4B-Instruct-2507_1774604815/checkpoint-30/chat_template.jinja
# Qwen_Qwen3-4B-Instruct-2507_1774604815/checkpoint-30/merges.txt
# Qwen_Qwen3-4B-Instruct-2507_1774604815/checkpoint-30/optimizer.pt
# Qwen_Qwen3-4B-Instruct-2507_1774604815/checkpoint-30/rng_state.pth
# Qwen_Qwen3-4B-Instruct-2507_1774604815/checkpoint-30/scaler.pt
# Qwen_Qwen3-4B-Instruct-2507_1774604815/checkpoint-30/scheduler.pt
# Qwen_Qwen3-4B-Instruct-2507_1774604815/checkpoint-30/special_tokens_map.json
# Qwen_Qwen3-4B-Instruct-2507_1774604815/checkpoint-30/tokenizer.json
# Qwen_Qwen3-4B-Instruct-2507_1774604815/checkpoint-30/tokenizer_config.json
# Qwen_Qwen3-4B-Instruct-2507_1774604815/checkpoint-30/trainer_state.json
# Qwen_Qwen3-4B-Instruct-2507_1774604815/checkpoint-30/training_args.bin
# Qwen_Qwen3-4B-Instruct-2507_1774604815/checkpoint-30/vocab.json
#
# sent 695.39M bytes  received 548 bytes  126.43M bytes/sec
# total size is 695.21M  speedup is 1.00

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other resources:
# 1. Looking to use Unsloth locally? Read our [Installation Guide](https://unsloth.ai/docs/get-started/install) for details on installing Unsloth on Windows, Docker, AMD, Intel GPUs.
# 2. Learn how to do Reinforcement Learning with our [RL Guide and notebooks](https://unsloth.ai/docs/get-started/reinforcement-learning-rl-guide).
# 3. Read our guides and notebooks for [Text-to-speech (TTS)](https://unsloth.ai/docs/basics/text-to-speech-tts-fine-tuning) and [vision](https://unsloth.ai/docs/basics/vision-fine-tuning) model support.
# 4. Explore our [LLM Tutorials Directory](https://unsloth.ai/docs/models/tutorials-how-to-fine-tune-and-run-llms) to find dedicated guides for each model.
# 5. Need help with Inference? Read our [Inference & Deployment page](https://unsloth.ai/docs/basics/inference-and-deployment) for details on using vLLM, llama.cpp, Ollama etc.
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
#
#   <b>This notebook is licensed <a href="https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0">AGPL-3.0</a></b>
# </div>
